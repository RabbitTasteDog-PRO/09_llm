# %% [markdown]
# # Checkpoint로 이어지는 LangGraph 대화 기억
#
# LangGraph의 `Persistence`는 한 번의 그래프 실행이 끝난 뒤에도 State를 보존하는 기능이다. 이전 대화를 State에 저장하면 다음 질문에서 같은 대화를 이어 갈 수 있다.
#
# ## 먼저 구분할 용어
#
# 대화 기억은 모델이 내용을 내부에 외우는 기능이 아니다. LangGraph runtime이 현재 작업 데이터인 State를 저장하고, 다음 호출 전에 다시 불러오는 구조이다.
#
# - `State`: Node들이 현재 실행에서 함께 읽고 갱신하는 작업 데이터이다. 이 실습에서는 `messages`가 대화 이력이다.
# - `Checkpointer`: State를 저장하고 불러오는 저장 관리자이다.
# - `Checkpoint`: 특정 실행 단계에서 저장한 State snapshot 하나이다.
# - `thread`: 같은 대화에 속한 Checkpoint history이다.
# - `thread_id`: 저장하거나 불러올 thread를 지정하는 key이다. 사용자 인증을 담당하지 않는다.
# - `StateSnapshot`: 저장된 Checkpoint를 `get_state()`로 읽었을 때 반환되는 조회 객체이다.
#
# 핵심 흐름은 `thread_id로 thread 선택 → Checkpointer가 최신 Checkpoint 복구 → State에 새 입력 병합 → 그래프 실행 → 새 Checkpoint 저장` 순서이다.
#
# `InMemorySaver`는 Checkpointer의 한 구현이며 Checkpoint를 현재 Python 프로세스의 RAM에 저장한다.
#
# 프로세스가 끝나면 사라지므로 수업과 개발에 적합하고, 운영 환경에서는 DB 기반 Checkpointer를 사용한다.
#
# Checkpoint는 한 thread 안에서 이어지는 `단기 기억`을 담당한다. 여러 thread에서 공유할 사용자 선호나 장기 정보는 Store가 담당한다.
#
# ### 대화 이어가기와 중단된 실행 재개의 차이
#
# 이 실습의 이어가기는 같은 `thread_id`로 새 `graph.invoke()`를 호출해 과거 State 위에서 `새 Turn을 시작하는 방식`이다.
#
# 중단된 Node를 `Command(resume=...)`로 재개하는 Human-in-the-loop의 resume와는 다르며, 후자는 다음 노트북에서 다룬다.
#
# ## 이번 실습에서 확인할 것
#
# 같은 `thread_id`를 재사용하면 이전 `messages`가 복구되고, 다른 `thread_id`를 사용하면 대화가 분리되는지 비교한다.
#
# 마지막에는 `graph.get_state()`로 저장된 최신 State를 직접 읽는다.

# %% [markdown]
# ## 실행 환경 준비
#
# Persistence가 있는 Tool loop를 실행할 패키지를 현재 Jupyter 커널 환경에 설치한다.
#
# - `langgraph`: 그래프와 `InMemorySaver`를 제공한다.
# - `langchain-openai`: OpenAI Chat Model을 연결한다.
# - `langchain-tavily`: 검색 Tool을 제공한다.
# - `python-dotenv`: `.env`의 설정을 환경 변수로 불러온다.
#
# DB에 저장하는 운영용 Checkpointer는 별도 패키지가 필요하지만, 이 실습은 RAM에 저장하는 `InMemorySaver`만 사용한다.

# %%
# %pip install -U langgraph langchain-openai langchain-tavily python-dotenv

# %% [markdown]
# ## 모델·검색 인증과 선택 추적 설정
#
# `.env`는 API key와 모델 ID를 코드 밖에서 관리하는 설정 파일이다. 아래 셀은 비밀값을 출력하지 않고 누락된 환경 변수의 이름만 검사한다.
#
# - `OPENAI_API_KEY`: Chat Model 호출에 필요한 필수값이다.
# - `TAVILY_API_KEY`: 검색 Tool 호출에 필요한 필수값이다.
# - `OPENAI_CHAT_MODEL`: 호출할 모델 ID이며 없으면 수업용 기본값을 사용한다.
# - `LANGSMITH_API_KEY`: 실행 추적에 사용하는 선택값이다. 없어도 그래프와 Checkpoint 실습은 실행된다.
#
# `setdefault()`는 환경 변수가 없을 때만 기본값을 넣는다. 따라서 이미 정해진 LangSmith 설정을 덮어쓰지 않는다.

# %%
import os
from dotenv import find_dotenv, load_dotenv

dotenv_path = find_dotenv(usecwd=True)
load_dotenv(
    dotenv_path,
    override=False,
)

if os.getenv("LANGSMITH_API_KEY"):
    os.environ.setdefault("LANGSMITH_TRACING", "true")
    os.environ.setdefault("LANGSMITH_PROJECT", "langgraph-memory")

OPENAI_CHAT_MODEL = os.getenv("OPENAI_CHAT_MODEL", "gpt-5.6-luna")

# %% [markdown]
# ## 그래프 밖에서 검색 Tool 점검하기
#
# `TavilySearch`는 검색어를 받아 웹 검색 결과를 반환하는 Tool이다. Checkpoint 실습에 들어가기 전에 Tool만 직접 호출해 인증·네트워크·반환 구조를 먼저 확인한다.
#
# `max_results=2`는 한 번의 검색에서 가져올 최대 결과 수이다. 결과 수를 줄이면 이후 ToolMessage에 저장되는 검색 문맥이 불필요하게 커지는 것을 막을 수 있다.

# %%
from langchain_tavily import TavilySearch

tavily_tool = TavilySearch(max_result=2)
# tavily.invoke({"query": "야야야 내나이가 어때서 노래 제목"})
tavily_tool.invoke({"query": "지금 서울 날씨는?"})
# Out:
# {'query': '지금 서울 날씨는?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.accuweather.com/ko/kr/seoul/226081/current-weather/226081',
#    'title': '서울특별시, 서울시, 대한민국 현재 날씨',
#    'content': '# 서울특별시, 서울시\n\nGamezop.com\n\n서울특별시\n\n서울시\n\n## 전 세계\n\n전 세계\n\n### 허리케인\n\n### 악천후 기상\n\n### 레이더 및 지도\n\n### 동영상\n\n# 현재 기상\n\nPM 10:43\n\n## 밤\n\n폭염 주의보\n\n바람남남서 4km/h\n\n돌풍15km/h\n\n강수 확률96%\n\n뇌우 확률28%\n\n강수1.3mm\n\n강수량1.3mm\n\n총 강수 시간2\n\n총 강수 시간2\n\n구름량54%\n\n### 저녁\n\n### 밤사이\n\n## 해와 달\n\n## 온도 기록\n\n## 전망\n\n전망\n\n### 시간별\n\n### 10일\n\n### 월\n\n## 전 세계\n\n전 세계\n\n### 허리케인\n\n### 악천후 기상\n\n### 레이더 및 지도\n\n### 동영상\n\n## 인근 지역:',
#    'score': 0.72254705,
#    'raw_content': None,
#    'id': '2749fa-00'},
#   {'url': 'https://korean.visitseoul.net/weather',
#    'title': '서울 실시간 날씨 정보 | 서울 공식 관광정보 웹사이트',
#    'content': '| 항목 | 오늘 : 2026-08-08 | 내일 : 2026-08-09 | 모레 : 2026-08-10 |\n| 날씨 | 구름많고 한때 소나기  구름많고 한때 소나기 | 맑음  맑음 | 구름많음  구름많음 |\n| 최저/최고기온 (℃) | 25℃ / 35℃ | 25℃ / 33℃ | 25℃ / 33℃ |\n| 강수확률 | 0% / 60% | 0% / 10% \n\n#### 대기오염 상세\n\n대기오염 상세 표 : 항목(오늘예보, 내일예보, 모레예보), 미세먼지(PM10), 초미세먼지(PM2.5)\n\n| 항목 | 오늘예보 | 내일예보 | 모레예보 |\n| 미세먼지 (PM10) | 미세먼지좋음 좋음 | 미세먼지좋음 좋음 | 미세먼지좋음 좋음 |\n| 초미세먼지 (PM2.5) | 초미세먼지좋음 좋음 | 초미세먼지좋음 좋음 | 초미세먼지좋음 좋음 |\n\n#### 주간예보\n\n주간예보 표 : 항목별 날짜, 날씨, 최저/최고기온(℃) [...] | 항목 | 2026-08-08 | 2026-08-09 | 2026-08-10 | 2026-08-11 | 2026-08-12 |\n| 날씨 | 구름많고 한때 소나기 구름많고 한때 소나기 | 맑음 맑음 | 구름많음 구름많음 | 맑음 맑음 | 맑음 맑음 |\n| 최저/최고기온 (℃) | 25℃ / 35℃ | 25℃ / 33℃ | 25℃ / 33℃ | 25℃ / 35℃ | 25℃ / 34℃ |\n\n제공 : 케이웨더(Kweather) [...] Family Site\n\nFamily Site; "메뉴 열기") \n\n 파트너스\n STO 소개\n 의료관광\n 서울관광 아카이브\n 서울관광플라자\n 디스커버서울패스\n 서울스테이\n 다누림관광\n 서울등산관광\n 서울컨벤션뷰로\n 서울컬쳐라운지\n Visit Seoul API\n SEOUL BLEISURE\n 서울미식주간\n\n전체보기메뉴 열기\n\n전체보기메뉴 열기\n\n## visitseoul.net\n\n### 검색순위\n\n### 나의찜하기\n\n찜하기는 관심 있는 여행 정보를 저장하여 서울의 주요 지역별로 탐색할 수 있는 기능입니다.\n\n나의 찜한 목록 바로가기\n\n서울의 날씨\n\n홈 >  여행정보 >  서울의 날씨\n\n서울의 날씨\n\n#### 3일 예보\n\n3일 예보 표 : 항목별(오늘, 내일, 모레) 날짜, 날씨, 최저/최고기온(℃), 강수확률',
#    'score': 0.70336664,
#    'raw_content': None,
#    'id': '3dfa27-01'},
#   {'url': 'https://www.ventusky.com/ko/seoul',
#    'title': '날씨 - 서울특별시 - 14일 예보: 기온, 바람 및 레이더',
#    'content': "기온\n 체감 온도\n 강수량\n 날씨 레이더\n Satellite\n 풍속\n 강풍\n 구름량\n 기압\n CAPE\n 적설량\n 습도\n 바다\n 대기 오염\n\n풍향 에니메이션   \n ECMWF, GFS, ICON, GEM\n\nNew Custom Color Scales in Ventusky Scale\n\n세계 / 대한민국 / 서울특별시 (Seoul)\n\n37°34'북 / 126°58'동 / 고도 44 m / 07:51 2026.08.18, Asia/Seoul (UTC+9)\n\n 현재 날씨\n 예보\n 해와 달\n\n|  |  |\n --- |\n| 안개 | 24.4 °C |\n|  |\n| 풍속   2 km/h |\n\n|  |  |\n --- |\n| 기압 | 1010 hPa |\n| 시계 | 7 km |\n| 구름량 | 60 % |\n\n기상대 정보 Seoul City, 거리: 1 km (07:00 2026.08.18)\n\n레이더 지도 열기\n\n## 다음 24시간 [...] |  |\n\n| 33 |\n| 31 |\n| 29 |\n| 27 |\n| 25 |\n| 23 |\n| 21 |\n| 19 |\n| 17 |\n\n|  |  |  |  |  |  |  |  |  |  |  |  |  |  |\n ---  ---  ---  ---  ---  ---  --- |\n| 화 18 구름이 거의 없는 맑은 하늘 | 수 19 대체로 흐림 | 목 20 대체로 흐림 | 금 21 흐리고 비 | 토 22 흐리고 비 | 일 23 비, 뇌우 가능성 있음 | 월 24 비, 뇌우 가능성 있음 | 화 25 흐리고 비 | 수 26 흐린 | 목 27 소나기와 섞여 | 금 28 구름이 거의 없는 맑은 하늘 | 토 29 구름이 거의 없는 맑은 하늘 | 일 30 맑은 하늘 | 월 31 구름이 거의 없는 맑은 하늘 |\n\n## 대기 오염 (AQI) [...] | 부분적으로 흐림 24 °C 0 mm 0 %  남  5 km/h | 부분적으로 흐림 25 °C 0 mm 0 %  남서  7 km/h | 부분적으로 흐림 26 °C 0 mm 10 %  남서  7 km/h | 부분적으로 흐림 27 °C 0 mm 10 %  남서  9 km/h | 부분적으로 흐림 28 °C 0 mm 0 %  남서  12 km/h | 부분적으로 흐림 29 °C 0 mm 0 %  남서  12 km/h | 구름이 거의 없는 맑은 하늘 30 °C 0 mm 0 %  서  14 km/h | 구름이 거의 없는 맑은 하늘 30 °C 0 mm 0 %  남서  15 km/h | 맑은 하늘 30 °C 0 mm 0 %  서  14 km/h | 맑은 하늘 29 °C 0 mm 0 %  서  14 km/h | 맑은 하늘 28 °C 0 mm 0 %  서  13 km/h | 구름이 거의 없는 맑은 하늘 26 °C 0 mm 0 %  서  11 km/h | 대체로 흐림 25 °C 0 mm 0 %  서",
#    'score': 0.6932451,
#    'raw_content': None,
#    'id': 'aa3d69-02'},
#   {'url': 'https://www.accuweather.com/ko/kr/seoul/226081/hourly-weather-forecast/226081',
#    'title': '서울특별시, 서울시, 대한민국 시간별 날씨',
#    'content': '# 서울특별시, 서울시\n\n서울특별시\n\n서울시\n\n## 전 세계\n\n전 세계\n\n### 허리케인\n\n### 악천후 기상\n\n### 레이더 및 지도\n\n### 동영상\n\n## 시간별\n\n## 오후 11시\n\nrain drop\n\n폭염 주의보\n\n바람북동 6km/h\n\n대기질완벽함\n\n돌풍15km/h\n\n습도85%\n\n이슬점22° C\n\nAccuLumen Brightness Index™0 (어둡게)\n\n구름량22%\n\n가시거리11km\n\n운저10100m\n\n## 전망\n\n전망\n\n### 내일\n\n### 토요일\n\n### 10일\n\n## 전 세계\n\n전 세계\n\n### 허리케인\n\n### 악천후 기상\n\n### 레이더 및 지도\n\n### 동영상\n\n## 인근 지역:',
#    'score': 0.6188962,
#    'raw_content': None,
#    'id': '23a42e-03'},
#   {'url': 'https://www.weather.go.kr/w/forecast/overall/short-term.do?stnId=109',
#    'title': '기상청 서울·인천·경기 단기예보',
#    'content': '##### 지역우선설정\n\n  현재위치 우선: PC브라우저의 위치정보나 스마트폰의 GPS정보로 현위치를 확인하여 표출합니다.  \n   관심지역 우선: 관심지역으로 추가된 지점을 우선 표출합니다.  \n   위치 미확인: 브라우저에서 위치확인을 요청하지 않습니다. 조회한 지역이 없을 경우 기상청 서울청사 위치를 보여줍니다.\n 탭우선설정 설명보기\n\n  닫기\n\n  ##### 탭우선설정\n\n  날씨 우선: 조회지점의 현재날씨 및 시계열 정보가 포함된 첫화면  \n   전국 우선: 전국지역의 날씨를 간략하게 표출\n 날씨아이콘 설명보기\n\n  닫기\n\n  ##### 날씨아이콘\n\n  3가지 타입의 날씨아이콘을 선택할 수 있습니다.\n 맑음 구름많음 흐림 비 비 또는 눈 눈 또는 비 눈 소나기 빗방울 빗방울/눈날림 눈날림\n 시간별 예보설정 설명보기\n\n  닫기\n\n  ##### 시간별 예보설정\n\n  3시간 간격: 시간별 예보를 3시간 간격으로 표출  \n   1시간 간격: 시간별 예보를 1시간 간격으로 표출 [...] | 예보요소 | 평년(오늘) | 어제(15일) | 오늘(16일) | 내일(17일) | 모레(18일) | 글피(19일) | 그글피(20일) |\n| 최저기온 (℃) | 20.3 ~ 24.3 | 22.0 ~ 25.5 | 21.0 ~ 23.1 | 22 ~ 24 | 22 ~ 25 | 22 ~ 25 | 22 ~ 25 |\n| 최고기온 (℃) | 29.3 ~ 31.3 | 25.6 ~ 31.5 | 23.8 ~ 29.2 | 29 ~ 31 | 30 ~ 33 | 30 ~ 33 | 30 ~ 34 |\n| 파고(m) | 인천·경기북부 앞바다 | 0.5~1.0 | 0.5~1.0 | 0.5 | 0.5 | 0.5 |\n| 인천·경기남부 앞바다 | 0.5~1.0 | 0.5~1.0 | 0.5 | 0.5 | 0.5 |\n| 충남북부 앞바다 | 0.5~1.0 | 0.5~1.0 | 0.5~1.0 | 0.5~1.0 | 0.5 | [...] ※ 최저/최고기온 설명\n  + 11시 발표 : 오늘의 최저기온은 03시~09시 사이에 관측된 아침 최저기온이며, 최고는 예보된 낮 최고기온임\n  + 17시 발표 : 오늘의 최저/최고기온은 관측된 아침최저/낮최고 기온이며, 아침 최저기온은 03시~09시 사이 가장 낮은 기온, 낮최고기온은 09시 이후 통보시(17시)까지 가장 높은 기온임\n  + 평년과 어제의 최저/최고기온은 일최저기온/일최고기온임\n  + ※ 체감온도: 기온에 습도, 바람 등의 영향이 더해져 사람이 느끼는 더위나 추위를 정량적으로 나타낸 온도, 습도 10%p 증가시마다 체감온도 1도가량 증가하는 특징\n\n지역검색 창 닫기\n\n검색 읍면동으로 선택\n\n시/도 구/군 읍면동\n\n 강원도\n 경기도\n 경상남도\n 경상북도\n 광주광역시\n 대구광역시\n 대전광역시\n 부산광역시\n 서울특별시\n 세종특별자치시\n 울산광역시\n 인천광역시\n 전라남도\n 전라북도\n 제주특별자치도\n 충청남도\n 충청북도\n\n※ 지역 선택이 안 될 경우: 클릭',
#    'score': 0.4959723,
#    'raw_content': None,
#    'id': 'fb98d2-04'}],
#  'response_time': 1.81,
#  'request_id': '61c12c63-486d-4152-9d1c-9a20fb1239cd'}

# %% [markdown]
# ## Chat Model에 검색 Tool 사용법 연결하기
#
# `bind_tools()`는 Chat Model에 Tool의 이름·설명·입력 schema를 알려 준다. 모델은 검색이 필요하다고 판단하면 `tool_calls`를 포함한 `AIMessage`를 반환한다.
#
# 이 단계는 Tool을 `실행`하지 않는다. 실제 Tool 호출은 뒤에서 등록할 `ToolNode`가 담당한다.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model=OPENAI_CHAT_MODEL, use_responses_api=True)

# llm 이 툴을 호출할수있게 bind함
tools = [tavily_tool]
llm_with_tools = llm.bind_tools(tools)

# %% [markdown]
# ## Checkpoint 대화 기억을 완성할 네 구성 요소
#
# 여기까지 만든 `llm_with_tools`는 Tool 요청을 만들 수 있지만, 대화 이력을 저장하거나 다음 호출에서 복구하지는 않는다. 기억이 있는 Tool loop를 만들려면 다음 네 구성 요소를 연결해야 한다.
#
# 1. `State`: 저장할 `messages`와 새 message를 합치는 규칙이다.
# 2. `chatbot`: 복구된 `messages`를 읽어 다음 `AIMessage`를 만드는 Node이다.
# 3. `Checkpointer`: 실행 단계별 State를 `thread_id`에 따라 저장하고 불러오는 객체이다.
# 4. `CompiledStateGraph`: Node·Edge를 실행하고 Checkpointer에 저장 시점을 알려 주는 runtime이다.
#
# ```text
# 새 HumanMessage + thread_id
#             ↓
# Checkpointer가 최신 Checkpoint의 messages 복구
#             ↓
# add_messages로 새 입력 병합 → chatbot ↔ tools
#             ↓
# 실행 단계별 새 Checkpoint 저장 → 최종 State 반환
# ```
#
# ### 1. Checkpoint에 저장할 messages State 규칙 정의하기
#
# Checkpointer가 저장하는 대상은 모델 자체가 아니라 `그래프 State`이다. <br>
# State는 `messages` key 하나만 가지며 사용자·모델·Tool message가 실행 순서대로 들어간다.
#
# - 입력: Checkpoint에서 복구한 기존 `messages`와 Node가 반환한 새 message이다.
# - 변환: `add_messages` reducer가 새 message를 기존 목록 뒤에 병합한다.
# - 출력: 다음 Node와 다음 Turn이 읽을 수 있는 갱신된 `messages`이다.
# - 다음 사용처: Checkpointer가 갱신된 State를 새 Checkpoint로 저장한다.
#
# 같은 `thread_id`의 Checkpoint를 복구한 뒤 새 입력을 넣어도 과거 대화가 사라지지 않는 이유가 이 병합 규칙이다.

# %%
from typing import Annotated, TypedDict

from langchain_core.messages import AnyMessage
from langgraph.graph.message import add_messages

class State(TypedDict):
    # AnyMessage : 스테이트가 가지는 키와 벨류를 정의
    messages: Annotated[list[AnyMessage], add_messages]

# %% [markdown]
# ### 2. 복구된 대화를 읽는 chatbot Node 정의하기
#
# `chatbot()`은 현재 thread의 `messages`를 모델에 전달하고 새 `AIMessage`를 State update로 반환한다. 뒤에서 `add_node()`로 등록하면 그래프의 Node가 된다.
#
# - 입력: Checkpoint에서 복구된 과거 message와 현재 Turn의 새 `HumanMessage`가 합쳐진 State이다.
# - 변환: `llm_with_tools`가 전체 대화를 읽고 일반 답변 또는 Tool 요청을 만든다.
# - 출력: `add_messages`에 전달할 새 `AIMessage` 하나이다.
# - 다음 사용처: Tool 요청 유무에 따라 Tool Node 또는 종료 경로로 이동하고, 갱신된 State는 Checkpoint에 저장된다.
#
# Node는 Checkpointer를 직접 호출하지 않는다. Node가 State update를 반환하면 LangGraph runtime이 실행 단계의 경계에서 저장을 요청한다. 이 셀은 함수 정의 단계이므로 모델 API는 아직 호출하지 않는다.

# %%
# 전달 받은 State에는 복구된 이전 대화 내욕이 담겨있다
def chatbot(state: State) -> dict:
    response = llm_with_tools.invoke(state["messages"])
    return {"messages": [response]}

# %% [markdown]
# ### 3. State를 저장할 Checkpointer 만들기
#
#
# ![LangGraph 공식 Checkpoint 구조](https://cdn.jsdelivr.net/gh/goat-skn-ai/image-repo@7f008bd902003af9b0138e956af0be37ffa7a9ff/08_llm/08_langgraph/01_langgraph_basics/04_official_checkpoints.png)
#
# 1. `Graph`: State가 Node와 Edge를 따라 이동한다.
# 2. `Super-step`: 현재 실행할 Node 묶음 하나가 한 단계가 된다. 순차 Node는 각각 별도 단계이다.
# 3. `Checkpoint`: 각 단계 경계에서 State·`next`·ID 등의 snapshot을 저장한다.
# 4. `Thread`: 같은 `thread_id`에 속한 Checkpoint들을 하나의 history로 관리한다.
# 5. `StateSnapshot`: 저장된 Checkpoint를 Python에서 조회할 때 사용하는 객체이다.
#
# 출처: [LangGraph Checkpointers 문서](https://docs.langchain.com/oss/python/langgraph/checkpointers)
#
# ---
#
# `InMemorySaver`는 위 Checkpoint들을 RAM에 저장하는 Checkpointer이다.
#
# - 입력: 컴파일된 그래프가 전달하는 `thread_id`와 실행 단계별 State snapshot이다.
# - 변환: 같은 `thread_id`의 Checkpoint들을 하나의 thread history로 구분해 보관한다.
# - 출력: 다음 호출에서 복구할 최신 Checkpoint와 조회 가능한 StateSnapshot이다.
# - 다음 사용처: `compile(checkpointer=checkpointer)`가 이 객체를 그래프 runtime에 연결한다.
#
# `InMemorySaver()` 객체를 만드는 것만으로는 아무 State도 저장되지 않는다. Python 프로세스가 끝나면 기록도 모두 사라지므로, 재시작 복구가 필요한 운영 서비스에는 PostgresSaver 같은 DB 기반 구현을 사용한다.

# %%
from langgraph.checkpoint.memory import InMemorySaver

# 현재 Jupyter server 메모리를 저장소로 사용
check_pointer = InMemorySaver()

# %% [markdown]
# ### 4. 네 구성 요소를 Persistence가 있는 Tool loop로 조립하기
#
# 이제 앞에서 정의한 부품을 `StateGraph`에 등록하고 Checkpointer와 함께 컴파일한다.
#
# `prebuilt`는 반복해서 사용하는 표준 로직을 LangGraph가 미리 구현해 둔 구성 요소이다.<br>
# `ToolNode`와 `tools_condition`를 직접 구현하지 않고 `langgraph.prebuilt`에서 제공되는 것을 사용한다.
#
# - `State` → `StateGraph(State)`의 공유 데이터 schema이다.
# - `chatbot` → 모델의 다음 행동을 만드는 `"chatbot"` Node이다.
# - `ToolNode(tools)` → 모델의 `tool_calls`를 실제 실행하는 `"tools"` Node이다.
# - `tools_condition` → Tool 실행과 종료 중 다음 경로를 고르는 route function이다.
# - `checkpointer` → `compile(checkpointer=...)`에서 thread별 Persistence를 담당한다.
#
# `ToolNode`와 `tools_condition`은 Tool 실행 흐름을 담당하고, 대화 기억은 `checkpointer`가 담당한다.
#
# ```text
# START → chatbot → tools_condition
#                     ├─ tools → chatbot
#                     └─ END
#
# 각 실행 단계의 State ── checkpointer ──> thread_id별 Checkpoint
# ```
#
# `compile()`의 출력은 실행 가능한 `CompiledStateGraph`이다. 이 셀에서는 구조만 조립하므로 모델·Tool 호출과 Checkpoint 저장은 일어나지 않는다. `checkpointer` 인자를 생략하면 `thread_id`를 전달해도 이전 State가 자동으로 복구되지 않는다.

# %%
from langgraph.graph import END, START, StateGraph
from langgraph.prebuilt import ToolNode, tools_condition

# Builder
workflow = StateGraph(State)


# 노트 등록
workflow.add_node("chatbot", chatbot)
# preBuilt ToolNode
workflow.add_node("tools", ToolNode(tools))

# 엣지 연결
workflow.add_edge(START, "chatbot")
workflow.add_edge("tools", "chatbot")

# 조건 분기 설정
workflow.add_conditional_edges(
    # 분기할 Node
    "chatbot",
    # "chatbot" Note에서 반환되는 마지막 AIMessage에
    # tool_calls가 있다면 "tools", 없으면 END
    tools_condition,
)


# 실행 가능한 형태로 변경
graph = workflow.compile(
    # 단계별 State를 thread_id기준 CheckPointer로 저장한다
    checkpointer=check_pointer
)

display(graph)

# %% [markdown]
# ## thread_id로 실제 저장·복구 흐름 확인하기
#
# 앞의 셀들은 기억에 필요한 규칙과 객체를 정의했다. 이제 `graph.invoke()`를 호출하면 처음으로 모델·Tool loop가 실행되고 Checkpointer가 State를 저장한다.
#
# 각 호출은 다음 순서로 처리된다.
#
# 1. 입력 State update와 `configurable.thread_id`를 받는다.
# 2. 같은 thread의 최신 Checkpoint가 있으면 State를 복구한다.
# 3. `add_messages`가 새 `HumanMessage`를 기존 이력 뒤에 합친다.
# 4. 그래프를 실행하고 단계별 State를 새 Checkpoint로 저장한다.
# 5. 누적된 `messages`를 포함한 최종 State를 반환한다.
#
# ### 1. user1 thread에 첫 번째 Turn 저장하기
#
# `Turn`은 사용자 입력과 그에 대한 모델 응답이 오가는 대화 한 차례이다. 첫 호출의 `thread_id`를 `user1`로 지정하고 이름이 포함된 `HumanMessage`를 전달한다.
#
# 아직 user1의 과거 Checkpoint가 없으므로 새 State에서 시작한다. `graph.invoke()`가 끝나면 실행 단계별 Checkpoint가 user1의 history에 추가되고, 최신 Checkpoint에는 사용자 입력과 모델 응답이 포함된다. 첫 Turn만으로는 기억을 증명할 수 없으므로 다음 셀에서 같은 `thread_id`를 재사용한다.

# %%
from langchain_core.messages import HumanMessage
from langchain_core.runnables import RunnableConfig

# CheckPointer가 user1의 저장 위치를 선택하게 하기 위한 설정이다.
# user_config:RunnableConfig = RunnableConfig(configurable={"thread_id": "user1"})
user_config: RunnableConfig = {"configurable": {"thread_id": "user1"}}

# LLM에게 전달한 첫 메세지(첫 turn)
user_input: State = {"messages": [HumanMessage(content="반가워 내 이름은 김뀨뀨야")]}

user1_state = graph.invoke(
    # 초기 state
    user_input,
    # user1 CheckPoint를 저장하고 불러올 thread 지정
    config=user_config,
)

user1_state["messages"][-1].content
# Out:
# [{'type': 'text',
#   'text': '다시 만나서 반가워요, 김뀨뀨님! 😊  \n오늘은 어떤 이야기를 나눠볼까요?',
#   'annotations': [],
#   'id': 'msg_06231ee28c79cd07006a83ef65ab1487d096709bb643435e4f',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 2. 같은 user1 thread에서 이전 이름 회상하기
#
# 후속 호출에는 새 질문만 전달한다. 그러나 같은 `user1_config`를 사용하므로 Checkpointer가 user1의 최신 Checkpoint를 불러오고, `add_messages`가 새 질문을 과거 대화 뒤에 병합한다.
#
# - 입력: 이름이 없는 새 질문과 `thread_id="user1"`이다.
# - 변환: user1의 과거 `messages` 복구 → 새 질문 병합 → chatbot 실행 순서이다.
# - 출력: 과거 이름을 근거로 만든 최신 `AIMessage`이다.
# - 다음 사용처: 이번 Turn까지 포함한 State가 user1의 새 Checkpoint로 저장된다.
#
# 답변에 첫 Turn의 이름이 반영되면 모델이 숨겨서 기억한 것이 아니라 `복구된 messages를 다시 읽은 것`이다.

# %%
user_input2: State = {"messages": [HumanMessage(content="내 이름이 뭐라고?")]}

user1_state = graph.invoke(user_input2, config=user_config)

# 메모리에 State(대화 내역)이 담겨있고
# LLM요청시마다 모든 대화 내역을 다시 담아서 전달한다 == Context
user1_state["messages"][-1].content
# Out:
# [{'type': 'text',
#   'text': '김뀨뀨님이에요! 😊',
#   'annotations': [],
#   'id': 'msg_06231ee28c79cd07006a83efcfb27c87d0a478857989d4e99e',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 3. 다른 user2 thread가 분리되는지 확인하기
#
# `thread_id="user2"`는 user1과 다른 Checkpoint history를 가리킨다. 같은 graph와 Checkpointer를 사용해도 `thread_id`가 다르면 user1의 messages를 불러오지 않는다.
#
# - 입력: 이름을 묻는 질문과 새 `thread_id="user2"`이다.
# - 변환: user2의 저장 기록만 조회하며, 기록이 없으므로 새 State에서 그래프를 실행한다.
# - 출력: user1의 이름을 근거로 사용하지 않은 최신 `AIMessage`이다.
# - 다음 사용처: user2의 첫 State가 user1과 별도의 Checkpoint로 저장된다.
#
# user2의 답변이 user1의 이름을 근거로 사용하지 않아야 thread 격리가 유지된 것이다. 단, `thread_id`는 저장 key일 뿐 인증 수단은 아니므로 서비스에서는 접근 권한을 별도로 검사해야 한다.

# %%
user222_config: RunnableConfig = {"configurable": {"thread_id": "user222"}}
user222_input: State = {"messages": [HumanMessage(content="내 이름이 뭐라고?")]}

user222_state = graph.invoke(user222_input, config=user222_config)

# 메모리에 State(대화 내역)이 담겨있고
# LLM요청시마다 모든 대화 내역을 다시 담아서 전달한다 == Context
user222_state["messages"][-1].content
# Out:
# [{'id': 'rs_05a512653565eb23006a83f10bb078819bbce45d6e081f805e',
#   'summary': [],
#   'type': 'reasoning',
#   'content': [],
#   'encrypted_content': 'gAAAAABqg_EMv4nTDFxX9uVm31dRxoPqz2-OH-GZkas3OxUVvwCzd1fNV1ccCFOTkpJloZhCBOwa3SmJVvPGuX3tESQshjkvf9RQ9IEsp8anl1d5uianMW3izEkp8qjnx3DEb9oR4PcVw3sXpOCes_ZKuklK5P8uv-lyfJ7wG6XjboH1plJBGMDKfpaxZNWTZ5SJB_CNJ8o5S2VvpldBtipwdymDqe09P9D8sXoCfuiTfKKuSZW31UZbehMcCRc159-ZhoyWPWq2W4RjTAXmI3rXdOKNdx_tOuQrTUY698Fr3LKjgWd8tTMnK2HlIiGt1NLWcJypCndlVBSD_mBmhnokrUPUvsU9Xd553uSDM5kUnPJMO4BAQ2y2T-B8KxegP9mpEuJJRh6g02GO7T-O9GxFSZgKH-OTl4ld_tbD0vRkClzgEXIShlnhB6ovSaiwHO7eRJc1Kj8qleraWvUIVNGU_3HjTb7UU68hGcy40gtidVJ1PVs2D0P7h3AgDKdWOX_b6oA-ZHSQmtTOoHY3mkYQxhLafE_aP7hrYK-cAvDhCix45OscYZTU1a78GHqwP0XY23tLQegEoPIC4fTI1wtqIJhWs8JyY5uYsTXDbPqZq6JFVeloup8XZNX7jO31DdEfuzWma5_l6nCWuWEolmDzxIsBC-nedVdC8AKCjWbkSMxRBCLQRi4VT0NqdkStVSurY1NsXM-RLIkUgphscl6G6DPLtZfvJdudNOXLz4w6A6ONl8caPap5biW5ZBSWDrMLR8wUwp5IiX_Fwr7Z_l1VD9ZVFmRPIQ00dUIX9gx9HN43ciw8FWL8DnBU3JUPzragP9e6UtD_ILHHSBmR7QRt730xNg_EPgSbhB2S-XQxvxUSm3Vq98rCoPw3r5d3G5DNNy3iO-YqeIFo1WWhrzDj-Kv_TgOeeaaopHBTM5uMlAi7X7K6oKgYQK1WbU3lEBgELUD9Yb0p3Rn2celtKhgpk2FY7Rg60xp9wKvraw2aZj51FKQW2R4_opTb2ca_C17hpWWytDBo4CZpz_JPksu04q6Lx4u-_hMAkp4qk6hFpgRZDa8-_3zaeubohCg4wuSQBnS_gRquBNsIKdzly8IntA8TXBPm-ImvzEApdmATco0I9-P4jb3a9D90eUqqwjjEmysZ-2bN9AEFAwYdBvsmwHZQx04gR8wYgx92gNR8ZNAJ6qHVWI5yfigAvNM5UkhfmBXmYogshfvu2d7a1OmZXa9FM_Z5Lw=='},
#  {'type': 'text',
#   'text': '아직 이름을 알려주지 않으셔서 모르겠어요.',
#   'annotations': [],
#   'id': 'msg_05a512653565eb23006a83f10be8a8819b9cbbc5fb77d31bee',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 4. user1 thread로 돌아와 세 번째 Turn 이어 가기
#
# user2 호출 뒤 다시 `user1_config`를 전달한다. Checkpointer는 호출 순서가 아니라 `thread_id`를 기준으로 저장 위치를 선택하므로 user1의 최신 Checkpoint를 다시 복구한다.
#
# - 입력: 새 주제와 이름 회상을 함께 요구하는 질문, `thread_id="user1"`이다.
# - 변환: user1의 두 Turn 복구 → 새 질문 병합 → 그래프 실행 순서이다.
# - 출력: 새 주제와 저장된 이름을 함께 반영한 최신 `AIMessage`이다.
# - 다음 사용처: 세 번째 Turn까지 포함한 State가 user1 history의 최신 Checkpoint가 된다.
#
# 이 결과로 서로 다른 thread의 호출이 중간에 끼어도 user1의 대화가 독립적으로 이어지는지 확인한다.

# %%
from IPython.display import Markdown, display
user_input3: State = {"messages": [HumanMessage(content="LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘")]}

user3_state = graph.invoke(user_input3, config=user_config)
last_message = user3_state["messages"][-1]

user_answer = "\n".join(
    block.get("text", "")
    for block in last_message.content_blocks
    if block.get("type") == "text"
)

display(Markdown(user_answer))
# Out:
# 이름은 **김뀨뀨님**이에요! 😊
#
# ### LangGraph 복습 계획
# 1. **개념**: State, Node, Edge 복습
# 2. **기초 실습**: 챗봇 그래프 만들기
# 3. **심화**: 조건부 분기, Memory, Tool 연동
# 4. **정리**: 미니 에이전트 프로젝트 구현

# %% [markdown]
# ## 저장된 최신 Checkpoint를 StateSnapshot으로 확인하기
#
# `Checkpoint`는 Checkpointer에 저장된 기록이고, `StateSnapshot`은 그 기록을 Python에서 조회할 때 받는 객체이다. `graph.get_state(user1_config)`는 user1 thread의 `최신 Checkpoint 하나`를 StateSnapshot으로 반환한다.
#
# `두 필드 확인`
#
# - `values`: 해당 시점의 실제 State 값이다. 여기에는 누적된 `messages`가 들어 있다.
# - `next`: 다음에 실행할 Node 이름의 tuple이다. 그래프가 정상 종료되었으면 빈 tuple `()`이고, 값이 남아 있으면 중단되었거나 이어서 실행할 Node가 있다는 뜻이다.
#
# 입력은 `thread_id="user1"`인 config이고, 출력은 조회 전용 StateSnapshot이다.
#
# ### history와 resume의 범위
#
# - `graph.get_state()`: thread의 최신 snapshot 하나를 조회한다.
# - `graph.get_state_history()`: 같은 thread에 쌓인 여러 snapshot을 순서대로 조회할 때 사용하는 별도 API이다. 이 실습에서는 호출하지 않는다.
# - 같은 `thread_id`의 새 `graph.invoke()`: 최신 State를 복구한 뒤 새 Turn을 실행하는 `대화 이어가기`이다.
# - `Command(resume=...)`: interrupt로 멈춘 실행에 사람의 값을 전달해 재개하는 `중단 지점 resume`이다. 다음 Human-in-the-loop 노트북에서 다룬다.
#
# Tool 호출 여부에 따라 message 수는 달라질 수 있으므로 고정 숫자보다 user1의 세 Turn이 순서대로 포함되는지를 확인한다.

# %%
user1_snapshot = graph.get_state(user_config)
print("msg count : ", len(user1_snapshot.values["messages"]))
display(user1_snapshot.values["messages"])
# END로 끝난 상태이기 때문에 다음 Node 없음
print("next nodes : ", user1_snapshot.next)
# Out:
# msg count :  18
# [HumanMessage(content='반가워 내 이름은 김뀨뀨야', additional_kwargs={}, response_metadata={}, id='f0ef63f8-83f8-40a1-aee1-eff7a410f5b5'),
#  AIMessage(content=[{'type': 'text', 'text': '반가워요, 김뀨뀨님! 😊 무엇을 도와드릴까요?', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83ee6486d487d0b9578a8b93005f8e', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83ee63cca887d09c1b33d71d19ecfb', 'created_at': 1787031139.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83ee63cca887d09c1b33d71d19ecfb', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1181, 'output_tokens': 25, 'total_tokens': 1206, 'input_token_details': {'cache_creation': 1178, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='반가워 내 이름은 김뀨뀨야', additional_kwargs={}, response_metadata={}, id='9f3f7d3e-438c-4088-b206-684ff2a418ac'),
#  AIMessage(content=[{'type': 'text', 'text': '다시 만나서 반가워요, 김뀨뀨님! 😊  \n오늘은 어떤 이야기를 나눠볼까요?', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83ef65ab1487d096709bb643435e4f', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83ef64cb4887d0a61c2b345a2fbcc6', 'created_at': 1787031396.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83ef64cb4887d0a61c2b345a2fbcc6', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1224, 'output_tokens': 33, 'total_tokens': 1257, 'input_token_details': {'cache_creation': 43, 'cache_read': 1178}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='내 이름이 뭐라고?', additional_kwargs={}, response_metadata={}, id='ca2c97ff-54fc-42c8-abee-622d51182a11'),
#  AIMessage(content=[{'type': 'text', 'text': '김뀨뀨님이에요! 😊', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83efcfb27c87d0a478857989d4e99e', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83efce0afc87d0ae70785fff3d0042', 'created_at': 1787031502.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83efce0afc87d0ae70785fff3d0042', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1269, 'output_tokens': 14, 'total_tokens': 1283, 'input_token_details': {'cache_creation': 45, 'cache_read': 1221}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='a3373ddf-0f6b-441f-bf16-3bb57b776300'),
#  AIMessage(content=[{'id': 'rs_06231ee28c79cd07006a83f1abc11c87d0b19c31b10aa0bf3e', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_GuDxH5Tgseb5wJcWyhJBBEn4JGvgzAuhl_M5BlY6oNK7WqGTI_g9_JxThUvfsIhe3-809rVQ6dDaJ_-tfi3ZgJATyq4HWVnLxN9sLJYbz8vnb_E1HFD3XBJei8CUh2CLZwIbu81O89P7VZsYg0f26GbRFl8phZSu263w4cM3Y5m1JLq_9TjhpenwQ_ommtLy906dFCAP0dkt7cs6G3RigMR0bdAo974u3_wMbV_BPVB6jq0_rHsxAx6G4VXeC7sMdUfc66hzFmKKLRkwq_-T-KjQqkDSANeSW4gk7tVgxyRR4Mhr4Ha_x3aeD4E_Ymo8DqQKWnyqxaTeYF3H-RVSLL1kOAChrr171CmQ9sBKL4OVksbNlHZ4cNuoy-0k2DrOGVjUa57JlZiX4Oz_MsRkDDlcx8GijaWjgzDvVbd6-WrFdQE_0kvP4B0-1joyRu5Ok33QoMXpYWS04sTl2oBqNUXmCCMXsuyHRyWS46KmDzxFW1GyevS5VGPsKy_vFxQ3W-Tc6WUMyN6ZvpiC9Aly931lr8GadjwtfK1FfDW_fsmzNBroRdNf0cbg9ovnCKiGCKa1V3gWM9S6vKzKOXxLEfpXQyUqll8Tmis1dAMOFygfRYukGxc2OBCsnnLSEbP98hWYlOSv6_-DHRnkMcYpVurtjNvvdpKvzQYxa-45a4FavRNk8XJfyjz3ndqur3vZ-cDIgNUAXHRBcPCwewguZ586vNl64S5w7nfOdRrtlrns_g_K3h9180NyIItNHW08sCnDkVqLY1gQjz5auEm6HR7uoyhqYQOyfyokPKXvrixouYXeG25o7RD7mv1XnSXoBVwUzNmywDV6_Q3T6qlZoN9VZdbCJ-N5xmpWldKzNnUkxPpHw0GH4qodOu8AQce3YYhSq1P-iPydhOJ3F6f_ePq8pNw7Y5v9B_vkwk38XYdF7KOUVq6pJOnvwc7tLvGNdCxZOLmKkY3QPnb2qsitmN5awIq0tK3SLcdSFhomCuweutD8pXTpxE-ronkjuuQr2Fpp-1RNKWj9vGYBdmSvB9SfdQyOytwQWvAEmRoXN2kyTxNtIegvX5-TLVzLxI5Mz3R_ZA9k-d9fk3fuD4Zwa0SR42FU23NmEY4q0sbx1E8G2IEkQFbyS7_VYqzH5fOjsXnt2eq3Xm8Nf4hEQN7Z3cIb9wbx_wR6aB2oWnl01e7_N4F8GMYqsD_SWhS7sLMPf1-N4pU29BLVW6tyQIs5mYrgaXeH8Y9wjxlgPuyAh564a6tTK9iOEnd83WS2ZCkZ_E0E8QOg1vqSbeOb_36mI08xebBNad74tGT6ppHU0qaiuz7v0ELkwg13b9emo1LPAEtw6Lp1wS5mrHGDTc-321bjW7NF0welMVjJfNbmjRfi4='}, {'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 간략 복습 계획\n1. **기초 개념**: 그래프, 노드, 엣지, 상태(State) 이해  \n2. **간단한 챗봇 구현**: `StateGraph`로 대화 흐름 만들기  \n3. **조건부 라우팅**: 상황에 따라 다음 노드를 선택하는 방법 복습  \n4. **메모리와 체크포인트**: 대화 상태 저장 및 이어가기  \n5. **실습 프로젝트**: 도구 호출이 가능한 간단한 에이전트 만들기  \n6. **복습 정리**: 주요 API와 실행 흐름을 직접 설명해 보기', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f1ac4f2087d0a13d5033a3b8becb', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f1ab015887d0ab234737a2e1c03a', 'created_at': 1787031979.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f1ab015887d0ab234737a2e1c03a', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1305, 'output_tokens': 205, 'total_tokens': 1510, 'input_token_details': {'cache_creation': 36, 'cache_read': 1266}, 'output_token_details': {'reasoning': 40}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='f9dc88e0-8116-429f-8af9-d06d1b906bc4'),
#  AIMessage(content=[{'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **핵심 개념**: State, Node, Edge 이해하기  \n2. **기본 그래프**: 간단한 챗봇 구현하기  \n3. **조건부 흐름**: Conditional Edge 복습하기  \n4. **상태 관리**: Checkpointer와 Memory 익히기  \n5. **실전 연습**: Tool을 사용하는 에이전트 만들기  \n6. **최종 정리**: 작은 프로젝트를 완성하며 복습하기', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f1e6f80487d0b9c88dd110a9ac54', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f1e6458487d08d015c59d4fd7d43', 'created_at': 1787032038.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f1e6458487d08d015c59d4fd7d43', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1532, 'output_tokens': 132, 'total_tokens': 1664, 'input_token_details': {'cache_creation': 227, 'cache_read': 1302}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='e14e818a-c31c-4415-9fd4-8a6dde1d96b9'),
#  AIMessage(content=[{'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **개념 복습**: State, Node, Edge  \n2. **기본 실습**: 간단한 챗봇 만들기  \n3. **흐름 제어**: 조건부 Edge와 순환 구조  \n4. **상태 저장**: Memory와 Checkpointer  \n5. **응용 실습**: Tool 연동 에이전트 구현  \n6. **마무리**: 미니 프로젝트로 전체 내용 복습하기', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f216af4c87d09c986f89fd6125d3', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f215de0c87d0892293005c42c08e', 'created_at': 1787032085.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f215de0c87d0892293005c42c08e', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1686, 'output_tokens': 127, 'total_tokens': 1813, 'input_token_details': {'cache_creation': 154, 'cache_read': 1529}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='cfcf2e98-0061-41ca-abf5-c5dc0b4cec3d'),
#  AIMessage(content=[{'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **핵심 개념**: State·Node·Edge 이해  \n2. **기본 구현**: 간단한 챗봇 만들기  \n3. **흐름 제어**: 조건부 분기와 순환 학습  \n4. **상태 관리**: Memory·Checkpointer 복습  \n5. **응용 실습**: Tool 연동 에이전트 구현  \n6. **최종 정리**: 미니 프로젝트 완성하기', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f253396c87d0a0cc1f1a09f42dea', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f25260ac87d0af7b8f252a4bae72', 'created_at': 1787032146.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f25260ac87d0af7b8f252a4bae72', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1835, 'output_tokens': 130, 'total_tokens': 1965, 'input_token_details': {'cache_creation': 149, 'cache_read': 1683}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='ce93db40-ed66-4fd2-88a1-a35955369a87'),
#  AIMessage(content=[{'id': 'rs_06231ee28c79cd07006a83f261a4e487d0b53ee6c8c4bd899b', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_JjHjMOE3JSy_MOL0mfsz_jDeKJb6ZvcCyvLEEXAGRdWeG3Ek3yLn0rjhIKP2Jza6J44XWUNR7VvX6iDVEUVfqDA_Neg_fHKcBMXcwqOxxYS_M88EKd8jjZXCErwy2tT_3zO6M-gWm9VfBgVFc_inHI4W5uy0AUjITFy-gV84_-aFr6e0DxteYPf43Ysv-g_EvBljJg71ypBrPhMH6LVn8M9eUwQ0IOM2Ri3BE9vwYVp6RfOfliXZ-6g-BrrgjENR6J_x-Zn8huOLupzf_Dq1Zo3KecEmZrYDArbU2KD3mFwVH7OYW81eIqCmchKzi0XeJTcax2-EoPmKkzP8VZHmT7se91_bnBBcW_ublU2auL5nwZPsl0Ugaay0Aj_O_Jf6f4cnVgol6AwUs1KTAi4EPikIZ_Fw48ZX11Q3r5FSY6qN6EjNlLHQlV9jHoYuQeK49bWjsQk0ez_yI6x3iD55XbTdSY0Rjwew4sRyh-216oabh9LmVmwCLJEVfq9JGQKuBSbApcnpmDhe6a8sjR17c1aQTPOyiRlo2kPVqa9qVrfrkjGcsWMX0A5V09ovkforO-Jnq676xPsSITAyiz3Eu9wm-caA1mkrLLdAqO4AkLsp9ZRvNre0jfpcAe9nEQRJgglFtt7ObngA3EPZcPpzfracr61qHZBEUii7_W_hrPUbjdtt_Wmzh9URAWPDH_zrztwaqnr-7_nAHTI5dLJtI9itupCDgZIbQncm0mHwQmpRMLxwMntnJS800SN0LNvnid3wsRl33u8kAp3nMpzsNg3Rz5enzD5Xu-T_hZ13ILOFXZyRMSOakCECjjHx-cpktt_tf76ETsDT7bZD9i7El2RQrft8-URgYjCLrgylXLWZw2i5wrU0NIUALLDSy86xqpD6hDQknTqcPN4lCNjR13DZM2_7H2dFVx89VF3LIe9fuQtZS-KsQxUYVGJdWQSdRaz9sqJrxNRRaPEw9FKYxiWn3iENkFDo9RvWt6o-0umNT1XOgXnL220p94hqNZmrIRtae47Ik9L-eBeoV-RG0hs8VbWTJ1pXF34JLX4aaZQeFrtfaZsZIaq3nrDezt1ydOMAI5Hv5ICprV19y2MIb49JjC1bC3mTH3DenMvg-hy2LeIsJ7KPBOsVZtrIXZDZ8g0AMPLOEFfPKZT22baCP2TZs-qm2jO6ABIUjJo_BeBKZ6a-HGg66O2wRZBRhfX2Wpi6reV1OigPCDHXQbHqe5atlFTvgj3cWcc3eyae8grVX_Azifhm09u_BylnqTeahQC-tBryZrTTcPAJIDRCJsKg=='}, {'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **기초**: State·Node·Edge 복습  \n2. **실습**: 간단한 챗봇 구현  \n3. **응용**: 조건부 흐름·Memory·Tool 연동 학습  \n4. **마무리**: 미니 에이전트 프로젝트 완성', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f262111c87d0948228d3b52751ed', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f260e17c87d0a2dc958c8f7da3a0', 'created_at': 1787032160.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f260e17c87d0a2dc958c8f7da3a0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1987, 'output_tokens': 122, 'total_tokens': 2109, 'input_token_details': {'cache_creation': 152, 'cache_read': 1832}, 'output_token_details': {'reasoning': 25}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='e008110f-426f-46fd-b3b5-6e5e05a2a53e'),
#  AIMessage(content=[{'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **개념**: State, Node, Edge 복습  \n2. **기초 실습**: 챗봇 그래프 만들기  \n3. **심화**: 조건부 분기, Memory, Tool 연동  \n4. **정리**: 미니 에이전트 프로젝트 구현', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f2955f7487d0a5e32e047323c34b', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f294d20c87d090b49675548a5e67', 'created_at': 1787032212.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f294d20c87d090b49675548a5e67', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2131, 'output_tokens': 93, 'total_tokens': 2224, 'input_token_details': {'cache_creation': 144, 'cache_read': 1984}, 'output_token_details': {'reasoning': 0}})]
# next nodes :  ()

# %%
user_input4: State = {
  "messages":[
    HumanMessage(content="리센느 메이 이뿌다")
  ]
}

user1_state = graph.invoke(user_input4, config=user_config)
user1_state["messages"][-1].text
# Out:
# '맞아, **리센느 메이 정말 예쁘지!** 😊  \n청초하면서도 세련된 분위기가 매력적인 것 같아.'

# %%
user1_snapshot = graph.get_state(
    user_config,
)

display(user1_snapshot.values["messages"])
# Out:
# [HumanMessage(content='반가워 내 이름은 김뀨뀨야', additional_kwargs={}, response_metadata={}, id='f0ef63f8-83f8-40a1-aee1-eff7a410f5b5'),
#  AIMessage(content=[{'type': 'text', 'text': '반가워요, 김뀨뀨님! 😊 무엇을 도와드릴까요?', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83ee6486d487d0b9578a8b93005f8e', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83ee63cca887d09c1b33d71d19ecfb', 'created_at': 1787031139.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83ee63cca887d09c1b33d71d19ecfb', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1181, 'output_tokens': 25, 'total_tokens': 1206, 'input_token_details': {'cache_creation': 1178, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='반가워 내 이름은 김뀨뀨야', additional_kwargs={}, response_metadata={}, id='9f3f7d3e-438c-4088-b206-684ff2a418ac'),
#  AIMessage(content=[{'type': 'text', 'text': '다시 만나서 반가워요, 김뀨뀨님! 😊  \n오늘은 어떤 이야기를 나눠볼까요?', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83ef65ab1487d096709bb643435e4f', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83ef64cb4887d0a61c2b345a2fbcc6', 'created_at': 1787031396.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83ef64cb4887d0a61c2b345a2fbcc6', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1224, 'output_tokens': 33, 'total_tokens': 1257, 'input_token_details': {'cache_creation': 43, 'cache_read': 1178}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='내 이름이 뭐라고?', additional_kwargs={}, response_metadata={}, id='ca2c97ff-54fc-42c8-abee-622d51182a11'),
#  AIMessage(content=[{'type': 'text', 'text': '김뀨뀨님이에요! 😊', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83efcfb27c87d0a478857989d4e99e', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83efce0afc87d0ae70785fff3d0042', 'created_at': 1787031502.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83efce0afc87d0ae70785fff3d0042', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1269, 'output_tokens': 14, 'total_tokens': 1283, 'input_token_details': {'cache_creation': 45, 'cache_read': 1221}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='a3373ddf-0f6b-441f-bf16-3bb57b776300'),
#  AIMessage(content=[{'id': 'rs_06231ee28c79cd07006a83f1abc11c87d0b19c31b10aa0bf3e', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_GuDxH5Tgseb5wJcWyhJBBEn4JGvgzAuhl_M5BlY6oNK7WqGTI_g9_JxThUvfsIhe3-809rVQ6dDaJ_-tfi3ZgJATyq4HWVnLxN9sLJYbz8vnb_E1HFD3XBJei8CUh2CLZwIbu81O89P7VZsYg0f26GbRFl8phZSu263w4cM3Y5m1JLq_9TjhpenwQ_ommtLy906dFCAP0dkt7cs6G3RigMR0bdAo974u3_wMbV_BPVB6jq0_rHsxAx6G4VXeC7sMdUfc66hzFmKKLRkwq_-T-KjQqkDSANeSW4gk7tVgxyRR4Mhr4Ha_x3aeD4E_Ymo8DqQKWnyqxaTeYF3H-RVSLL1kOAChrr171CmQ9sBKL4OVksbNlHZ4cNuoy-0k2DrOGVjUa57JlZiX4Oz_MsRkDDlcx8GijaWjgzDvVbd6-WrFdQE_0kvP4B0-1joyRu5Ok33QoMXpYWS04sTl2oBqNUXmCCMXsuyHRyWS46KmDzxFW1GyevS5VGPsKy_vFxQ3W-Tc6WUMyN6ZvpiC9Aly931lr8GadjwtfK1FfDW_fsmzNBroRdNf0cbg9ovnCKiGCKa1V3gWM9S6vKzKOXxLEfpXQyUqll8Tmis1dAMOFygfRYukGxc2OBCsnnLSEbP98hWYlOSv6_-DHRnkMcYpVurtjNvvdpKvzQYxa-45a4FavRNk8XJfyjz3ndqur3vZ-cDIgNUAXHRBcPCwewguZ586vNl64S5w7nfOdRrtlrns_g_K3h9180NyIItNHW08sCnDkVqLY1gQjz5auEm6HR7uoyhqYQOyfyokPKXvrixouYXeG25o7RD7mv1XnSXoBVwUzNmywDV6_Q3T6qlZoN9VZdbCJ-N5xmpWldKzNnUkxPpHw0GH4qodOu8AQce3YYhSq1P-iPydhOJ3F6f_ePq8pNw7Y5v9B_vkwk38XYdF7KOUVq6pJOnvwc7tLvGNdCxZOLmKkY3QPnb2qsitmN5awIq0tK3SLcdSFhomCuweutD8pXTpxE-ronkjuuQr2Fpp-1RNKWj9vGYBdmSvB9SfdQyOytwQWvAEmRoXN2kyTxNtIegvX5-TLVzLxI5Mz3R_ZA9k-d9fk3fuD4Zwa0SR42FU23NmEY4q0sbx1E8G2IEkQFbyS7_VYqzH5fOjsXnt2eq3Xm8Nf4hEQN7Z3cIb9wbx_wR6aB2oWnl01e7_N4F8GMYqsD_SWhS7sLMPf1-N4pU29BLVW6tyQIs5mYrgaXeH8Y9wjxlgPuyAh564a6tTK9iOEnd83WS2ZCkZ_E0E8QOg1vqSbeOb_36mI08xebBNad74tGT6ppHU0qaiuz7v0ELkwg13b9emo1LPAEtw6Lp1wS5mrHGDTc-321bjW7NF0welMVjJfNbmjRfi4='}, {'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 간략 복습 계획\n1. **기초 개념**: 그래프, 노드, 엣지, 상태(State) 이해  \n2. **간단한 챗봇 구현**: `StateGraph`로 대화 흐름 만들기  \n3. **조건부 라우팅**: 상황에 따라 다음 노드를 선택하는 방법 복습  \n4. **메모리와 체크포인트**: 대화 상태 저장 및 이어가기  \n5. **실습 프로젝트**: 도구 호출이 가능한 간단한 에이전트 만들기  \n6. **복습 정리**: 주요 API와 실행 흐름을 직접 설명해 보기', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f1ac4f2087d0a13d5033a3b8becb', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f1ab015887d0ab234737a2e1c03a', 'created_at': 1787031979.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f1ab015887d0ab234737a2e1c03a', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1305, 'output_tokens': 205, 'total_tokens': 1510, 'input_token_details': {'cache_creation': 36, 'cache_read': 1266}, 'output_token_details': {'reasoning': 40}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='f9dc88e0-8116-429f-8af9-d06d1b906bc4'),
#  AIMessage(content=[{'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **핵심 개념**: State, Node, Edge 이해하기  \n2. **기본 그래프**: 간단한 챗봇 구현하기  \n3. **조건부 흐름**: Conditional Edge 복습하기  \n4. **상태 관리**: Checkpointer와 Memory 익히기  \n5. **실전 연습**: Tool을 사용하는 에이전트 만들기  \n6. **최종 정리**: 작은 프로젝트를 완성하며 복습하기', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f1e6f80487d0b9c88dd110a9ac54', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f1e6458487d08d015c59d4fd7d43', 'created_at': 1787032038.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f1e6458487d08d015c59d4fd7d43', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1532, 'output_tokens': 132, 'total_tokens': 1664, 'input_token_details': {'cache_creation': 227, 'cache_read': 1302}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='e14e818a-c31c-4415-9fd4-8a6dde1d96b9'),
#  AIMessage(content=[{'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **개념 복습**: State, Node, Edge  \n2. **기본 실습**: 간단한 챗봇 만들기  \n3. **흐름 제어**: 조건부 Edge와 순환 구조  \n4. **상태 저장**: Memory와 Checkpointer  \n5. **응용 실습**: Tool 연동 에이전트 구현  \n6. **마무리**: 미니 프로젝트로 전체 내용 복습하기', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f216af4c87d09c986f89fd6125d3', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f215de0c87d0892293005c42c08e', 'created_at': 1787032085.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f215de0c87d0892293005c42c08e', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1686, 'output_tokens': 127, 'total_tokens': 1813, 'input_token_details': {'cache_creation': 154, 'cache_read': 1529}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='cfcf2e98-0061-41ca-abf5-c5dc0b4cec3d'),
#  AIMessage(content=[{'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **핵심 개념**: State·Node·Edge 이해  \n2. **기본 구현**: 간단한 챗봇 만들기  \n3. **흐름 제어**: 조건부 분기와 순환 학습  \n4. **상태 관리**: Memory·Checkpointer 복습  \n5. **응용 실습**: Tool 연동 에이전트 구현  \n6. **최종 정리**: 미니 프로젝트 완성하기', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f253396c87d0a0cc1f1a09f42dea', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f25260ac87d0af7b8f252a4bae72', 'created_at': 1787032146.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f25260ac87d0af7b8f252a4bae72', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1835, 'output_tokens': 130, 'total_tokens': 1965, 'input_token_details': {'cache_creation': 149, 'cache_read': 1683}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='ce93db40-ed66-4fd2-88a1-a35955369a87'),
#  AIMessage(content=[{'id': 'rs_06231ee28c79cd07006a83f261a4e487d0b53ee6c8c4bd899b', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_JjHjMOE3JSy_MOL0mfsz_jDeKJb6ZvcCyvLEEXAGRdWeG3Ek3yLn0rjhIKP2Jza6J44XWUNR7VvX6iDVEUVfqDA_Neg_fHKcBMXcwqOxxYS_M88EKd8jjZXCErwy2tT_3zO6M-gWm9VfBgVFc_inHI4W5uy0AUjITFy-gV84_-aFr6e0DxteYPf43Ysv-g_EvBljJg71ypBrPhMH6LVn8M9eUwQ0IOM2Ri3BE9vwYVp6RfOfliXZ-6g-BrrgjENR6J_x-Zn8huOLupzf_Dq1Zo3KecEmZrYDArbU2KD3mFwVH7OYW81eIqCmchKzi0XeJTcax2-EoPmKkzP8VZHmT7se91_bnBBcW_ublU2auL5nwZPsl0Ugaay0Aj_O_Jf6f4cnVgol6AwUs1KTAi4EPikIZ_Fw48ZX11Q3r5FSY6qN6EjNlLHQlV9jHoYuQeK49bWjsQk0ez_yI6x3iD55XbTdSY0Rjwew4sRyh-216oabh9LmVmwCLJEVfq9JGQKuBSbApcnpmDhe6a8sjR17c1aQTPOyiRlo2kPVqa9qVrfrkjGcsWMX0A5V09ovkforO-Jnq676xPsSITAyiz3Eu9wm-caA1mkrLLdAqO4AkLsp9ZRvNre0jfpcAe9nEQRJgglFtt7ObngA3EPZcPpzfracr61qHZBEUii7_W_hrPUbjdtt_Wmzh9URAWPDH_zrztwaqnr-7_nAHTI5dLJtI9itupCDgZIbQncm0mHwQmpRMLxwMntnJS800SN0LNvnid3wsRl33u8kAp3nMpzsNg3Rz5enzD5Xu-T_hZ13ILOFXZyRMSOakCECjjHx-cpktt_tf76ETsDT7bZD9i7El2RQrft8-URgYjCLrgylXLWZw2i5wrU0NIUALLDSy86xqpD6hDQknTqcPN4lCNjR13DZM2_7H2dFVx89VF3LIe9fuQtZS-KsQxUYVGJdWQSdRaz9sqJrxNRRaPEw9FKYxiWn3iENkFDo9RvWt6o-0umNT1XOgXnL220p94hqNZmrIRtae47Ik9L-eBeoV-RG0hs8VbWTJ1pXF34JLX4aaZQeFrtfaZsZIaq3nrDezt1ydOMAI5Hv5ICprV19y2MIb49JjC1bC3mTH3DenMvg-hy2LeIsJ7KPBOsVZtrIXZDZ8g0AMPLOEFfPKZT22baCP2TZs-qm2jO6ABIUjJo_BeBKZ6a-HGg66O2wRZBRhfX2Wpi6reV1OigPCDHXQbHqe5atlFTvgj3cWcc3eyae8grVX_Azifhm09u_BylnqTeahQC-tBryZrTTcPAJIDRCJsKg=='}, {'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **기초**: State·Node·Edge 복습  \n2. **실습**: 간단한 챗봇 구현  \n3. **응용**: 조건부 흐름·Memory·Tool 연동 학습  \n4. **마무리**: 미니 에이전트 프로젝트 완성', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f262111c87d0948228d3b52751ed', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f260e17c87d0a2dc958c8f7da3a0', 'created_at': 1787032160.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f260e17c87d0a2dc958c8f7da3a0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1987, 'output_tokens': 122, 'total_tokens': 2109, 'input_token_details': {'cache_creation': 152, 'cache_read': 1832}, 'output_token_details': {'reasoning': 25}}),
#  HumanMessage(content='LangGraph 복습 계획 간력히 세우고 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='e008110f-426f-46fd-b3b5-6e5e05a2a53e'),
#  AIMessage(content=[{'type': 'text', 'text': '이름은 **김뀨뀨님**이에요! 😊\n\n### LangGraph 복습 계획\n1. **개념**: State, Node, Edge 복습  \n2. **기초 실습**: 챗봇 그래프 만들기  \n3. **심화**: 조건부 분기, Memory, Tool 연동  \n4. **정리**: 미니 에이전트 프로젝트 구현', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f2955f7487d0a5e32e047323c34b', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f294d20c87d090b49675548a5e67', 'created_at': 1787032212.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f294d20c87d090b49675548a5e67', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2131, 'output_tokens': 93, 'total_tokens': 2224, 'input_token_details': {'cache_creation': 144, 'cache_read': 1984}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='리센느 원이 파이리 닮았어?', additional_kwargs={}, response_metadata={}, id='1a83fdc1-aa6c-481b-9fd1-a5f52d33c459'),
#  AIMessage(content=[{'id': 'rs_06231ee28c79cd07006a83f7766e2087d087f6efb68ec9c430', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_d4BHonKx18uPq3nZb9o2CyGsB9Q9fTEMWhq7-nMpBZfYxBjymap48kjFC7xPU__eA_A02-V5f59poAz2BHcYV0I2t2hQ_KRlaFUuF6dSuQbPIB1HKohgDOQOfjEOfdq49lIY97v9kdVag11WaYj62GZxLrIjipzRF_MkHtfbz_KBtTH1UctUIhxb0YWoKfEN5DZ5fTYRKzPM6qW5WpxWxGyV3mlesH7FbWfGGO4YSolgrJp9WiuV2VZbNyi6yWIKWDkhuSFBFws89Ls0iEI_Pujcc3hmqMTuA-XY6CWw0tMvRIytp5Y3QnNWB56C2PZen1DfnT8_yZRwGZ41NTsvQWbmbFVXb5Uoq_W2up6Rw9wItedNYDHj5MZWMKzFOeIwUz8kDTHYF0IOGyqpy5yMaKeVJ7-4WN_p5hYhwAOS639QDlbynN2W3Jb1rJmTkjzi7FYCJjR5RS_Rm5t5SJNnHiUv4SIRC5BH20KYoFdQvL0mzttP4WRXA5uWMINuqUaKR8BiWm-s7GIqvutFh_SK1q6GTKfrcd4_tWlKZvQfPFSgJfc7NQqdQ0-OyY7K_U6gtgh_ZG01TF2Xd0X2pfKZfE0AWDHWI33Ung9C0iMu1_I3RqtuWbljafgOE4CblcxfYF74oJzIJb65v8-VA3UE6vNKgLBjhf_PDhz1DAce4EZF01YZHqxggBtv10evr_bxDKavRyYxOTHgDrq_uc1pQjxMhqi2xctUL5SScsNhPBk419gAXzJa77OstNl3LEezCz84gKQIm9ot5XQAKrZnLMBp6-TfYIkzotRxRBqKL-2yZn8RZwQvLjDJCvO1wm450DEUCvlxIlpH3Vzah5u1i5zmFMkthDDPXnBMONDPdD7nwhExdplGZ1K8QNniIZmhfyuaeMS5cIFCsBEhTtdYl1By4ZCilVhL7KcddX3jEdGcSzTGoDmxh6JB3gYeQuTirztKhjtwvVPbOfcfJsMrrKw5xdqsVpg0dB4xjZz2bUqY0ixlyQKV2LyVXCNuGL6XAE9PNRv0oQAYRvGmF-cMpULQHeyhcXUrESZo7UYrB4Ji6bvQeIbzR-e3PcGnOEO2aFNHybre8vcBl-EZVyi3-xKxuGIEy97U6Qguhv-Ygw3SvvMtBEVwdt729_vHIWGy3DugB8jGSBtxAFeKdhHkO1d4Do_MVcn5bGVRWRVDgHlRGxPKDNh0_RRSZx6BCSf1RL4clWx0IVdUDzdSAskpgrSodbOrBIcHbsXe8O36gx9qtQ2YRSY2jLZdDlewFGQPhEs00zDAJ51iDxUU6IN2n56rgUG8EYehhIB9lwFMtsFscfFTFmz6l7z4z2DNLSPo0WaGSB-8Dvq4Dq-B8INwcjXLW1_u3O42x_gL81oiXLLja5ra96ptDtVeDi4p0pwntZ9EOY0eDd5tB1xB_16VIVYQloDHV_zH41n3-U4OTT9Ssi5pvEzGp_2OGikmU7MMtT4-ZVUxUyWxypRzcH83TzuBP_xg3PpEsuewYm4WUbe5HlEUDg2fqWwCZ-GcMMjh7Fh0kccVTNy507fxFwU0pkF1_Sim79-w-5CHsGDq7DYh2R7AGZqxkNU_UxrR-5qSM5MoEV8Bo_jxUGaUjArNTkmQ=='}, {'type': 'text', 'text': '응, **리센느 원이 파이리 닮았다는 말이 조금 이해돼!** 😊  \n특히 **동그란 눈과 귀여운 표정, 상큼한 분위기**가 파이리 느낌이 있는 것 같아. 물론 완전히 똑같다기보다는 귀여운 이미지가 비슷한 정도야.', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f7776a1c87d092e1193d89e567b4', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f775931087d081e59431c92f5241', 'created_at': 1787033461.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f775931087d081e59431c92f5241', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2243, 'output_tokens': 165, 'total_tokens': 2408, 'input_token_details': {'cache_creation': 112, 'cache_read': 2128}, 'output_token_details': {'reasoning': 83}}),
#  HumanMessage(content='리센느 원이 파이리 닮았어?', additional_kwargs={}, response_metadata={}, id='3d2e4387-8509-4f24-bec4-7da1b8460b9a'),
#  AIMessage(content=[{'type': 'text', 'text': '개인적인 느낌이지만, **리센느 원이 파이리와 닮았다고 볼 수 있어요!** 🐲  \n특히 귀여운 표정과 발랄하고 상큼한 분위기가 비슷해요. 다만 외모보다는 **전체적인 이미지와 분위기**가 닮은 쪽에 가까워요.', 'annotations': [], 'id': 'msg_06231ee28c79cd07006a83f79f9b8487d08e61e74eb8773369', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_06231ee28c79cd07006a83f79ed74087d0813aa902aa3c4b01', 'created_at': 1787033502.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_06231ee28c79cd07006a83f79ed74087d0813aa902aa3c4b01', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2427, 'output_tokens': 82, 'total_tokens': 2509, 'input_token_details': {'cache_creation': 184, 'cache_read': 2240}, 'output_token_details': {'reasoning': 0}})]
