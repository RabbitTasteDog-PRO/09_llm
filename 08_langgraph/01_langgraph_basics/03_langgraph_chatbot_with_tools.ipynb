# %% [markdown]
# # Tool 호출 루프가 있는 LangGraph Chatbot
#
# 일반 Chat Model은 질문을 읽고 답변을 한 번 생성한다. Tool이 연결된 Chat Model은 답변에 외부 정보가 필요하면 검색이나 계산 같은 기능의 `실행 요청`을 만들 수 있다.
#
# 모델이 Tool을 직접 실행하는 것은 아니다. <br>
# 모델은 `AIMessage.tool_calls`를 만들고, LangGraph의 Tool Node가 요청을 실행해 `ToolMessage`로 돌려준다. <br>
# 모델은 그 결과를 다시 읽고 최종 답변을 만들거나 다른 Tool을 요청한다.

# %% [markdown]
# ## 패키지 설치
#
# Tool loop에 필요한 LangGraph, OpenAI와 Tavily 통합을 설치한다. 이 셀은 외부 검색이나 유료 모델을 호출하지 않는다.

# %%
# %pip install -U langgraph langchain-openai langchain-tavily python-dotenv
# Out:
# Requirement already satisfied: langgraph in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (1.2.11)
# Requirement already satisfied: langchain-openai in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: langchain-tavily in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (0.2.18)
# Requirement already satisfied: python-dotenv in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (1.2.3)
# Requirement already satisfied: langchain-core<2,>=1.4.7 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph) (1.5.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: certifi in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-openai) (3.2.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: httpx2<3,>=2.7.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (2.10.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.70.0)
# Requirement already satisfied: httpcore2==2.10.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (2.10.0)
# Requirement already satisfied: truststore>=0.10 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (0.10.4)
# Requirement already satisfied: regex in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-tavily) (3.14.3)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from langchain-tavily) (1.3.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.24.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/choejiheum/miniforge3/envs/llm_env/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## OpenAI와 Tavily 인증 준비
#
# `.env` 또는 운영체제 환경 변수에서 필수 키를 불러온다. 값 자체는 출력하지 않고, LangSmith가 없을 때도 그래프의 핵심 경로는 유지한다.

# %%
import os
from dotenv import find_dotenv, load_dotenv

dotenv_path = find_dotenv(usecwd=True)
load_dotenv(dotenv_path, override=False)

if os.getenv("LANGSMITH_API_KEY"):
    os.environ.setdefault("LANGSMITH_TRACING", "true")
    os.environ.setdefault("LANGSMITH_PROJECT", "langgraph-tool-chat")

OPENAI_CHAT_MODEL = os.getenv("OPENAI_CHAT_MODEL", "gpt-5.6-luna")

# %% [markdown]
# ## Tavily Tool의 입력과 반환 구조
#
# Tavily(태빌리)는 AI 애플리케이션이 최신 웹 문서를 검색하도록 제공하는 검색 서비스이다.<br>
# `TavilySearch`는 이 서비스를 LangChain Tool 형식으로 감싼 객체이다.
#
# - `Tool`: 모델에 보여 줄 이름·설명·입력 규칙과 실제 Python 실행 기능을 함께 가진 객체이다.
# - `args_schema`: Tool이 받을 수 있는 인자 이름과 자료형을 정의한 입력 스키마이다. `TavilySearch`에서는 `query` 등의 값을 검사하고, `bind_tools()`가 모델에 전달할 함수 설명의 근거가 된다.
# - `invoke()` 입력: `query`가 담긴 딕셔너리이다.
# - `invoke()` 출력: 검색어와 `results` 목록 등이 담긴 딕셔너리이다.
#
# Agent에 연결하기 전에 직접 호출하면 Tavily 인증·입력 문제를 뒤의 모델 판단이나 그래프 연결 문제와 분리할 수 있다.

# %%
from langchain_tavily import TavilySearch

# 웹 검색 도구
tavily_tool = TavilySearch(
    # 관련 내용 최대 2건 검색
    max_result=2,
)

# taily 실행
tavily_tool.invoke(
    {
        # 검색 쿼리 등록
        "query": "LangGraph에서 노드란 무엇인가?"
    }
)
# Out:
# {'query': 'LangGraph에서 노드란 무엇인가?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.ibm.com/kr-ko/think/topics/langgraph',
#    'title': 'LangGraph란 무엇인가요?',
#    'content': '순환 그래프: 순환 그래프는 순환을 하나 이상 포함하는 그래프로, 에이전트 런타임에 필수적입니다. 이는 동일한 노드에서 시작하고 끝나면서 루프를 형성하는 경로가 그래프 안에 존재한다는 의미입니다. 복잡한 워크플로에는 순환 종속성이 포함되어 있는 경우가 많으며, 루프의 이전 단계에 따라 다음 단계의 결과가 달라집니다.\n\n노드: LangGraph에서 노드는 AI 워크플로 안에 있는 개별 구성 요소 또는 에이전트를 나타냅니다. 노드는 특정 방식으로 상호 작용하는 "행위자"라고 볼 수 있습니다. 예를 들어 툴 호출을 위한 노드를 추가할 땐 ToolNode를 사용할 수 있습니다. 또 다른 예로, 다음 노드는 현재 노드 다음에 실행될 노드를 가리킵니다.\n\n엣지: 엣지는 현재 상태에 따라 다음에 실행할 노드를 결정하는 Python 내의 함수입니다. 엣지는 조건부 분기 또는 고정적인 전환일 수 있습니다.\n\n#### 툴 [...] ## LangGraph 확장 방법\n\nLangGraph는 그래프 기반 아키텍처를 사용하여 사용자가 효율성을 저하시키지 않으면서 인공 지능 워크플로를 확장하도록 지원합니다. LangGraph는 노드 간의 복잡한 관계를 모델링하여 의사 결정을 향상시킵니다. 즉, AI 에이전트를 사용하여 이 노드들의 과거 행동과 피드백을 분석합니다. LLM의 세계에서는 이 프로세스를 성찰(reflection)이라고 합니다.\n\n의사 결정: LangGraph는 노드 간의 복잡한 관계를 모델링하여 보다 효과적인 의사 결정 시스템을 구축하기 위한 프레임워크를 제공합니다.\n\n유연성 향상: 개발자가 새로운 구성 요소를 통합하고 기존 워크플로를 조정할 수 있는 오픈 소스 특성과 모듈식 디자인을 갖췄습니다. [...] #### 툴\n\nRAG: 검색 증강 생성(RAG)은 관련 문서를 검색하고 답변 생성을 위한 인풋으로 사용해서, LLM의 기능을 외부 소스의 컨텍스트 정보와 결합합니다.\n\n워크플로: 워크플로는 AI 워크플로를 정의하는 노드 상호작용의 시퀀스입니다. 노드를 워크플로에 배열하면 개별 구성 요소의 강점을 사용하는 좀 더 복잡하고 동적인 워크플로를 만들 수 있습니다.\n\nAPI: LangGraph는 사용자가 프로그래밍 방식으로 구성 요소와 상호 작용하게 하는 API 세트를 제공합니다. 사용자는 API 키를 사용하고, 새 노드를 추가하고, 기존 워크플로를 수정하고, AI 워크플로에서 데이터를 검색할 수 있습니다.',
#    'score': 0.90771407,
#    'raw_content': None,
#    'id': '5a72e9-00'},
#   {'url': 'https://lsjsj92.tistory.com/696',
#    'title': '랭그래프(LangGraph)란? LangGraph의 개념과 사용 방법 예제 ...',
#    'content': "상태 (State): 그래프의 '메모리'입니다. 그래프의 각 단계를 거치면서 데이터가 어떻게 변하고 유지되는지를 정의하는 객체입니다. 대화 기록, 중간 결과, 사용자 정보 등 에이전트가 작업을 수행하는 동안 기억해야 할 모든 정보가 이 상태에 담깁니다. 보통 파이썬의 TypedDict를 사용하여 명확한 구조로 정의합니다.\n 노드 (Nodes): 그래프의 '작업 단위'입니다. 특정 작업을 수행하는 Python 함수라고 생각할 수 있습니다. 노드는 현재의 상태(State)를 입력받아, LLM을 호출하거나 도구를 사용하는 등의 작업을 처리한 뒤, 변경된 상태를 반환합니다.\n 엣지 (Edges): 노드와 노드를 연결하는 '경로'입니다. 정보와 제어 흐름이 어떤 순서로 이어질지를 결정합니다.\n\n## 예제 코드로 LangGraph 작동 방식 이해하기 [...] 관리 메뉴\n\n 글쓰기\n 방명록\n RSS\n 관리\n\n## 꿈 많은 사람의 이야기\n\n## 랭그래프(LangGraph)란? LangGraph의 개념과 사용 방법 예제(example) 본문\n\n인공지능(AI)/AI Agent\n\n### 랭그래프(LangGraph)란? LangGraph의 개념과 사용 방법 예제(example)\n\n이수진의 블로그 2025. 7. 27. 16:29\n\n반응형\n\n## 포스팅 개요\n\n이번 포스팅에서는 랭체인(LangChain) 생태계의 라이브러리인 랭그래프(LangGraph)에 대해서 알아봅니다. LangGraph란 무엇인지 알아보고, LangGraph를 사용하여 LLM 애플리케이션의 로직과 흐름을 명확하게 제어하는 방법을 알아봅니다. 특히 LangGraph의 핵심 구성 요소인 상태(State), 노드(Node), 엣지(Edge)에 대해 자세히 살펴보고, LLM을 연동하여 간단한 챗봇 에이전트(Agent)를 만들어보는 예제 코드를 살펴봅니다. [...] ```\nfrom typing import List, Annotated from typing_extensions import TypedDict from langchain_core.messages import AnyMessage class AgentState(TypedDict): # 'messages'는 대화 기록을 저장하는 리스트입니다. messages: Annotated[List[AnyMessage], lambda x, y: x + y] turn_count: int\n```\n\n messages: 사용자와 AI의 대화 기록을 list 형태로 계속 축적해 나갑니다. Annotated와 lambda 함수 lambda x, y: x + y는 LangGraph가 새로운 메시지를 기존 리스트에 자동으로 더해주도록 하는 편리한 기능입니다.\n turn\\_count: 대화 턴 수를 기록하는 정수 값입니다.\n\n### 3. 에이전트 노드(Node) 정의",
#    'score': 0.84277284,
#    'raw_content': None,
#    'id': '57e2f4-01'},
#   {'url': 'https://bcho.tistory.com/1486',
#    'title': '고급 Agent를 위한 Langgraph 개념 이해 #2 - Node',
#    'content': '# 조대협의 블로그\n\n빅데이타 & 머신러닝/생성형 AI (ChatGPT etc)\n\n## 고급 Agent를 위한 Langgraph 개념 이해 #2 - Node\n\nTerry Cho 2025. 7. 8. 16:42\n\n# 2. Node\n\nNode는 State 정보를 활용해서, State 정보를 변경하거나 action을 취하는 그래프내의 함수이다. \n\n함수내에서는 LLM 모델을 실행해서 질문에 대한 정답을 찾거나 , Tool 등을 이용해서 Action을 취하거나, 또는 RAG를 통해서 질문에 필요한 추가 컨택스트 정보를 검색해와서 State에 저장해서 다음 Node에서 LLM이 답변에 활용할 수 있도록 한다. [...] 예를 들어 web\\_search,chat 이라는 Node가 있을때, web\\_search Node에서는 Google 검색을 이용하여, 질문에 필요한 추가 정보를 검색해서 State에 저장한후, 다음 chat 노드에서 해당 State에 저장된 Context 정보를 리턴하는 식으로 구현이 된다. \n\nNode는 Python function으로 정의되며, 입력 parameter는 State 타입을 사용하며, 리턴은 State 정보의 스키마를 따르는 Dictionary나 TypedDict를 데이터 형으로 사용한다. \n\n아래 그림은 노드를 Pseudo 코드로 간단하게 구현해 놓은 예제이다. [...] 별도의 벡터 데이터베이스를 설정한 후에, 캐쉬에 저장되는 키 값에 대한 임베딩 벡터를 벡터데이터 베이스에 저장하고, 새롭게 질의된 문장의 임베딩 값을 계산해서, 벡터데이터베이스에 기 저장된 문장의 임베딩값과 비교한다. \n\n아래 코드는 벡터데이터베이스에서 새롭게 질의된 문장과 유사한 문장을 검색하는 코드이다. \n\n```\nsearch_results = vector_store.similarity_search_with_score(question, k=1)\n```\n\n만약에 검색된 결과가 SIMLARITY\\_THRESHOLD (기준값) 이상이면, 기존에 저장된 질문을 캐쉬 값으로 리턴한다.',
#    'score': 0.80126834,
#    'raw_content': None,
#    'id': '4b7aac-02'},
#   {'url': 'https://dacon.io/en/edu/472',
#    'title': 'AI 에이전트와 LangGraph의 기초 (1) - DACON',
#    'content': '## 이번 교재에서 배워요.\n\n스테이지 1~2\n\n### LangGraph란 무엇인가요?\n\n• LangGraph의 등장 배경과 필요성 이해  \n • LangChain과 LangGraph의 구조적 차이 비교  \n • 상태(State), 노드(Node), 엣지(Edge) 등 핵심 개념 습득  \n • 복잡한 AI 애플리케이션을 그래프 기반으로 설계하는 방식 체험\n\n스테이지 3~4\n\n### 메시지와 상태 다루기\n\n• LangChain의 메시지 타입(HumanMessage, AIMessage 등) 이해  \n • 메시지를 시간 순서대로 누적하는 구조 학습  \n • 상태(state) 객체에 대화 메시지를 저장하고 갱신하는 방식 실습  \n • 모델에 대화 기록을 전달하고 응답을 받아오는 방법 체험\n\n스테이지 5~6\n\n### 상태 기반 대화 흐름 만들기 [...] ✓\n\n대화 내용을 자동으로 저장하고 이어가는 구조를 직접 구성할 수 있어요\n\n✓\n\nLLM(예: GPT)에게 도구를 연결해서, “파리 여행지 추천해줘” 같은 요청에 자동으로 도구를 실행하게 할 수 있어요\n\n✓\n\nLangGraph의 노드(Node)와 엣지(Edge)를 활용해 간단한 그래프 기반 AI 구조를 구성할 수 있어요\n\n## 이런 분들에게 추천해요.\n\nLLM + 툴 사용 예제를 차근차근 따라해보고 싶은 비전공자\n\nLLM 기반 프로젝트를 처음 시작하는 분\n\n에이전트(Agent) 자동화에 입문하고 싶은 초보자\n\n챗봇 그 이상, ‘도구를 쓰는 AI’를 만들고 싶은 개발자\n\n### 프로젝트 과정\n\n차근차근 단계를 밟아 학습해보세요.\n\n스테이지 11 개\n\n1. LangGraph 실습을 위한 개념 다지기\n\n2. QUIZ - LangGraph 개념 이해하기\n\n3. 메시지와 모델 기초\n\n4. QUIZ - 메시지와 모델 기초 이해하기 [...] • LangGraph에서 메시지를 자동으로 누적 관리하는 MessagesState 구조 이해  \n • 상태 기반 그래프 설계 도구 StateGraph 사용법 습득  \n • LLM을 호출하는 노드를 생성하고, 그래프 흐름에 연결해 실행  \n • 메시지를 append하지 않아도 자동으로 누적되는 구조 체험\n\n스테이지 7~8\n\n### LangGraph에서 도구 호출 처리하기\n\n• LLM이 자연어를 해석해 외부 도구를 자동으로 선택하고 호출하는 구조 이해  \n • @tool 데코레이터를 이용한 도구 등록 방식 학습  \n • LangGraph에서 LLM과 ToolNode를 결합해 실제로 도구를 실행하는 흐름 구현  \n • 복합 명령에서 여러 도구를 동시에 호출하는 구조 실습  \n • 도구 호출 판단을 LLM에게 맡기고, LangGraph에서 흐름을 통합 제어하는 방식 체득\n\n스테이지 9~10\n\n### 조건 분기와 도구 자동화를 결합한 LangGraph 흐름 만들기',
#    'score': 0.7206637,
#    'raw_content': None,
#    'id': '6e2ec3-03'},
#   {'url': 'https://www.youtube.com/watch?v=W_uwR_yx4-c',
#    'title': '#LangGraph 개념 완전 정복 몰아보기(3시간) - YouTube',
#    'content': '✅ 타임라인 00:00 LangGraph 개요 21:29 LangGraph 세부 기능(State, Node, Edge, Conditional Edge, Compile) 46:56 LangGraph 로 자유롭게 그래프 로직 구성(흐름 엔지니어링) 1:10:30 Naive RAG(전통적인 방식의 RAG) 를 LangGraph 로 구현 1:31:43 답변의 할루시네이션 관련성 평가 모듈 추가 1:43:28 웹 검색 노드 추가 1:51:37 쿼리 재작성 모듈 추가 2:00:55 [프로젝트] Agentic RAG - 에이전트를 활용한 RAG 2:24:50 [프로젝트] Adaptive RAG #agent#rag --- 📍 "테디노트의 RAG 비법노트" 랭체인 강의:  📘 랭체인 한국어 튜토리얼(무료 전자책):  📝 테디노트(깃헙 블로그) :  💻 GitHub 소스코드 저장소:  \n\n...more Show less \n\n## Chapters\n\nView all [...] ## In this video\n\nChapters\n\nTranscript\n\n## Chapters\n\nImage 14 ### LangGraph 개요 ### LangGraph 개요 0:00\n\n### LangGraph 개요\n\n0:00\n\nImage 15 ### LangGraph 세부 기능(State, Node, Edge, Conditional Edge, Compile) ### LangGraph 세부 기능(State, Node, Edge, Conditional Edge, Compile) 21:29\n\n### LangGraph 세부 기능(State, Node, Edge, Conditional Edge, Compile)\n\n21:29\n\nImage 16 ### LangGraph 로 자유롭게 그래프 로직 구성(흐름 엔지니어링) ### LangGraph 로 자유롭게 그래프 로직 구성(흐름 엔지니어링) 46:56\n\n### LangGraph 로 자유롭게 그래프 로직 구성(흐름 엔지니어링)\n\n46:56 [...] ### LangGraph 개요\n\n0:00\n\nImage 9 ### LangGraph 세부 기능(State, Node, Edge, Conditional Edge, Compile) ### LangGraph 세부 기능(State, Node, Edge, Conditional Edge, Compile) 21:29\n\n### LangGraph 세부 기능(State, Node, Edge, Conditional Edge, Compile)\n\n21:29\n\nImage 10 ### LangGraph 로 자유롭게 그래프 로직 구성(흐름 엔지니어링) ### LangGraph 로 자유롭게 그래프 로직 구성(흐름 엔지니어링) 46:56\n\n### LangGraph 로 자유롭게 그래프 로직 구성(흐름 엔지니어링)\n\n46:56\n\nImage 11 ### Naive RAG(전통적인 방식의 RAG) 를 LangGraph 로 구현 ### Naive RAG(전통적인 방식의 RAG) 를 LangGraph 로 구현 1:10:30',
#    'score': 0.5272928,
#    'raw_content': None,
#    'id': '7caaea-04'}],
#  'response_time': 0.72,
#  'request_id': '5451715c-5a29-4596-b547-e39f4b371aaa'}

# %% [markdown]
# ## Tool 스키마를 Chat Model에 연결하기
#
# ### 호출 전에 넣는 `tools`
#
# - `tools`: 모델이 선택할 수 있도록 전달하는 Tool 객체 목록이다.
# - `bind_tools(tools)`: 각 Tool의 이름·설명·`args_schema`를 모델 요청에 포함한 새 Runnable을 만든다.
#
# ### 호출 뒤에 나오는 `tool_calls`
#
# - `tool_calls`: 모델이 `tools`를 보고 만든 실행 요청 목록이다.
#     - 이름이 비슷하지만 Tool 객체 목록이 아니라 `모델의 출력`이며, 이 단계에서는 Python Tool이 아직 실행되지 않았다.
#     - 실제 실행은 뒤의 Tool Node가 맡는다.

# %%
from langchain_openai import ChatOpenAI

# 1. llm 모델 객체 생성
llm = ChatOpenAI(
    # 모델등록
    model=OPENAI_CHAT_MODEL,
    # 최신 api 사용할건지
    use_responses_api=True,
)

# 2. llm에게 전달할 tool 목록 생성
tools = [
    tavily_tool,
]

# 3. llm과 tool 목록이 연결된 새 Runnable 생성
llm_with_tools = llm.bind_tools(tools)

print("llm : ", type(llm).__name__)
print("llm_with_tools : ", type(llm_with_tools).__name__)
# Out:
# llm :  ChatOpenAI
# llm_with_tools :  _ChatModelBinding

# %% [markdown]
# ## Tool 호출 루프를 완성할 네 구성 요소
#
# 여기까지 만든 `llm_with_tools`는 Tool의 이름·설명·입력 스키마를 알고 `실행 요청을 작성할 수 있는 모델`이다. `bind_tools()`는 Tool을 모델에 알려 줄 뿐 Tavily를 실행하지 않는다.
#
# 모델의 요청을 실제 실행하고 그 결과를 다시 모델에게 전달하려면 다음 네 구성 요소가 필요하다.
#
# 1. `State`: 질문·Tool 요청·Tool 결과·최종 답변을 이어 주는 공유 메시지 규칙이다.
# 2. `chatbot`: State를 읽어 일반 답변 또는 `tool_calls`가 담긴 `AIMessage`를 만드는 Node이다.
# 3. `ToolNode`: `tool_calls`를 읽어 실제 Tool을 실행하고 `ToolMessage`를 만드는 Node이다.
# 4. `tools_condition`: 최신 `AIMessage`에 Tool 요청이 있는지 보고 다음 경로를 정하는 route function이다.
#
# ```text
# HumanMessage → chatbot → AIMessage → tools_condition
#                          ├─ tool_calls 있음 → ToolNode → ToolMessage → chatbot
#                          └─ tool_calls 없음 → END
# ```
#
# 다음 네 셀에서는 이 부품을 `정의만` 하므로 화면 출력이나 외부 호출이 발생하지 않는다. 뒤의 `네 구성 요소를 Tool 호출 루프로 조립하기`에서 `StateGraph`에 등록하고 `compile()`한 뒤, `graph.invoke()`를 호출할 때 하나의 반복 구조로 동작한다.
#
# ### 1. 대화 이력을 합칠 State 규칙 정의하기
#
# `State`는 Node 사이에서 공유하는 데이터 구조이다. 이 셀에서는 메시지를 직접 저장하지 않고, 그래프 실행 중 새 message를 기존 목록에 합치는 규칙을 선언한다.
#
# - 저장 대상: `HumanMessage`(질문), `AIMessage`(답변 또는 Tool 요청), `ToolMessage`(Tool 결과)이다.
# - 실행 시 입력: 기존 `messages`와 Node가 반환한 새 message이다.
# - 변환: `add_messages` reducer가 두 값을 실행 순서대로 합친다.
# - 출력: 다음 Node가 읽을 수 있는 갱신된 `messages`이다.
# - 다음 사용처: Tool 결과가 추가된 뒤 `chatbot`이 이전 질문과 요청까지 함께 읽는다.

# %%
from typing import Annotated, TypedDict

from langchain_core.messages import AnyMessage
from langgraph.graph.message import add_messages


class State(TypedDict):
    # AnyMessage : 스테이트가 가지는 키와 벨류를 정의
    messages: Annotated[list[AnyMessage], add_messages]

# %% [markdown]
# ### 2. 모델의 다음 행동을 정하는 chatbot Node 만들기
#
# `chatbot`은 현재 State의 전체 `messages`를 `llm_with_tools`에 전달하는 Node이다. 모델은 일반 답변 또는 `tool_calls`가 담긴 `AIMessage`를 만들지만, 이 Node가 Tool을 직접 실행하지는 않는다.
#
# - 입력: `HumanMessage`·`AIMessage`·`ToolMessage`가 누적된 현재 State이다.
# - 변환: 모델이 지금 답할지 Tool 실행을 요청할지 결정한다.
# - 출력: 새 `AIMessage` 하나이다.
# - 다음 사용처: `add_messages`가 State에 합치고 `tools_condition`이 다음 경로를 판단한다.
#
# 첫 호출에서는 Tool 요청을 만들 수 있고, Tool 결과가 State에 추가된 뒤 다시 호출되면 그 결과를 근거로 최종 답변을 만들 수 있다. 이 셀은 함수 정의 단계이므로 모델 API는 아직 호출하지 않는다.

# %%
# # 현재 대화를 읽고 AIMessage Update를 반환하는
# # Chatbot Node용 함수를 정의
# def chatbot(state: State) -> dict:
#     # State에 누적된 대화(list[AniMessage])를 LLM에게 입력
#     # response == AIMessage
#     response = llm.invoke(state["messages"])
#     # State의 'messages'를 업데이트하기 위한 값을 반환
#     # Node 실행 후 add_messages (reducer)가 기존 목록과 병합을 수행
#     return {"messages": [response]}

def chatbot(state: State) -> dict:
    # State의 메시지를 tool이 묶여있는 LLM에 전달
    # -> tool 사용 조건은 아래에서 정의할 예정
    response = llm_with_tools.invoke(state["messages"])
    return {"messages": [response]}

# %% [markdown]
# ### 3. Tool 요청을 실제 실행하는 Tool Node 만들기
#
# `chatbot`이 만든 `tool_calls`는 `실행 요청`일 뿐 실제 검색 결과가 아니다. `ToolNode`는 요청의 Tool 이름과 인자를 읽고 허용된 Python Tool을 실행한 뒤, 결과를 `ToolMessage`로 바꾸는 Node이다.
#
# ```text
# tool_calls의 name·args·id
#         ↓ 이름으로 Tool 선택
# tool.invoke(args)
#         ↓ 결과와 같은 호출 ID 연결
# ToolMessage(content, tool_call_id=id)
# ```
#
# - 입력: 최신 `AIMessage.tool_calls`의 `name`·`args`·`id`이다.
# - 변환: `name`으로 허용된 Tool을 찾고 `tool.invoke(args)`로 실행한다.
# - 출력: 실행 결과와 같은 호출 ID를 담은 `ToolMessage` 목록이다.
# - 다음 사용처: `add_messages`가 결과를 State에 합치고 `tools → chatbot` Edge가 모델로 돌려보낸다.
#
# 이 Node는 Tool 요청의 유무를 판단하지 않는다. 뒤의 `tools_condition`이 `tool_calls`가 있을 때만 이 Node로 보낸다. 내부 원리를 확인하기 위해 직접 구현하며, 노트북 마지막에는 같은 역할의 LangGraph 기본 제공 `ToolNode`로 교체한다.

# %%
import json

from langchain_core.messages import ToolMessage

class ToolNode:
    """AIMessage.tool_calls를
    허용된 python tool(함수) 결과로 바꾸는 Node이다
    """

    # 1. 전달 받은 tool 목록을
    #   {tool 이름 : 실제 tool 함수} 형태의 dict로 변환
    def __init__(self, tools):
        self.tools_by_name = {
            tool.name: tool for tool in tools
        }

    # 2. __call__(): 객체를 함수처럼 호출할 수 있게하는 메서드
    # ex) tool_node = ToolNode(tools)
    #     tool_node.__call__() == tool_node()
    def __call__(self, state:State):
        # 요청 읽기: state에 messages가 없으면 []
        #          있으면 마지막 message를 tool 요청으로 사용
        messages = state.get("messages", [])

        if not messages:
            raise ValueError("State에 messages가 없습니다.")

        # state의 마지막 메시지
        request_message = messages[-1]

        # 3. Tool 실행:
        # 각 tool_calls의 name, args, id를 차례대로 처리

        outputs = [] # tool 요청 결과를 저장할 list

        for tool_call in request_message.tool_calls:
            tool_name = tool_call["name"]

            if tool_name not in self.tools_by_name:
                raise ValueError(
                    f"허용되지 않은 Tool 요청입니다: {tool_name}")

            # args: args schema 검사를 거쳐 Tool이 입력할 값 (dict)
            tool_result = self.tools_by_name[tool_name].invoke(
                tool_call["args"]
            )

            # 4. tool 결과를 ToolMessage로 변환하여 outputs 누적
            outputs.append(
                ToolMessage(
                    # 결과를 만든 Tool 이름
                    name = tool_name,

                    # Tool 결과(dict)를 JSON으로 변환
                    content = json.dumps(
                        tool_result,
                        ensure_ascii=False,
                    ),

                    # tool 요청 id
                    tool_call_id = tool_call["id"]
                )
            )

        # 5. State 갱신 값을 반환
        # -> ToolNode 종료 후 add_messages가
        #    State['messages'] 제일 뒤에 outputs 추가(갱신 작업)
        return {"messages": outputs}

# 6. ToolNode 노드 생성
tool_node = ToolNode(tools)

# %% [markdown]
# ### 4. Tool 실행 여부를 판단하는 route function 만들기
#
# `tools_condition`은 Conditional Edge 자체가 아니라, 현재 State를 읽고 `다음 목적지 label만 반환하는 함수`이다.
#
# - 입력: `chatbot`이 방금 추가한 최신 `AIMessage`이다.
# - 변환: `tool_calls` 목록이 비어 있는지 확인한다.
# - 출력: 요청이 있으면 `"tools"`, 없으면 `END`를 반환한다.
# - 다음 사용처: `add_conditional_edges()`가 반환값을 실제 목적지와 연결한다.
#
# 이 함수는 Tool을 실행하거나 State를 수정하지 않는다. 실제 Conditional Edge는 뒤에서 `add_conditional_edges()`가 반환값과 목적지를 연결할 때 만들어진다. 이 셀도 함수 정의 단계이므로 화면 출력은 없다.

# %%
from langgraph.graph import END


# 마지막 AIMessage의 tool_calls 유무로 다음 경로를 결정하는
# route Function 정의
def tools_condition(state: State):
    # 1. 분기를 판단한 message channel 읽기
    messages = state.get("messages", [])
    if not messages:
        raise ValueError("조건을 판정할 messages가 존재하지 않음")
    # 2. chatbot Node에서 추가한 마지막 메시지(AIMessage) 꺼내기
    last_message = messages[-1]

    # 3. 마지막 메세지가 tool_calls가 맞는지 확인
    has_tool_calls = bool(
        # last_message에서 tool_calls얻어오기, 없으면 []
        getattr(last_message, "tool_calls", [])
    )

    print(f"has_tool_calls: {has_tool_calls}")
    # 4. has_tool_calls가 True 이면 Node Label
    #    False이면 END를 반환
    return "tools" if has_tool_calls else END

# %% [markdown]
# ## 네 구성 요소를 Tool 호출 루프로 조립하기
#
# 앞의 네 셀은 부품의 역할만 정의했다. 이제 `StateGraph(State)`에 두 Node를 등록하고, route function의 반환값을 실제 목적지에 연결한다.
#
# - `State` → `StateGraph(State)`: 모든 Node가 공유할 message 규칙이다.
# - `chatbot` → `add_node("chatbot", chatbot)`: 다음 `AIMessage`를 만드는 Node이다.
# - `tool_node` → `add_node("tools", tool_node)`: Tool 요청을 실행하는 Node이다.
# - `tools_condition` → `add_conditional_edges(...)`: `tools` 또는 `END` 경로를 선택한다.
# - Tool 결과 재입력 → `add_edge("tools", "chatbot")`: `ToolMessage`를 모델이 다시 읽게 한다.
#
# ### `add_conditional_edges()`의 세 인자 읽기
#
# `add_conditional_edges()`는 `특정 Node가 끝난 뒤 route function을 실행하고, 반환값에 맞는 다음 목적지로 이동하라`는 규칙을 등록한다.
#
# 이 코드를 작성하는 시점에는 분기나 Tool 실행이 일어나지 않고, 뒤에서 `graph.invoke()`가 실행될 때 사용된다.
#
# - 첫 번째 인자 `"chatbot"`: 어느 Node가 끝난 뒤 분기할지 지정한다.
# - 두 번째 인자 `tools_condition`: 현재 State를 받아 `"tools"` 또는 `END`를 반환한다.
# - 세 번째 인자 `path_map`: route function의 `반환값을 실제 목적지로 바꾸는 딕셔너리`이다.
#   - 왼쪽 값: `tools_condition`이 반환한 값이다.
#   - 오른쪽 값: LangGraph가 실제로 이동할 Node 이름 또는 종료 지점이다.
#
# ```text
# chatbot 실행 완료
#     ↓
# tools_condition(state)
#     ├─ "tools" 반환 → path_map["tools"] → "tools" Node 실행
#     └─ END 반환     → path_map[END]     → 그래프 종료
# ```
#
# 따라서 `{"tools": "tools", END: END}`는 `"tools"`가 나오면 이름이 `"tools"`인 Node로 이동하고,
#
# `END`가 나오면 실행을 끝내라는 분기표이다. 현재는 반환값과 목적지 이름이 같지만, 둘의 역할을 구분해 보여 주기 위해 명시적으로 작성한다.
#
# `StateGraph`는 State 스키마를 기준으로 Node와 Edge를 등록하는 builder이다. 등록만으로 실행되지는 않으며 `compile()`해야 호출 가능한 그래프가 된다.
#
# ![LangGraph 공식 Agent Workflow](https://cdn.jsdelivr.net/gh/goat-skn-ai/image-repo@7f008bd902003af9b0138e956af0be37ffa7a9ff/08_llm/08_langgraph/01_langgraph_basics/langgraph_official_agent_loop.png)
#
# 1. `In`: 뒤의 실행 셀에서 `initial_state`에 담은 사용자 질문이 들어온다.
# 2. `LLM call`: `chatbot` Node가 답변 또는 `AIMessage.tool_calls`를 만든다.
# 3. `action`: Tool 요청이 생기면 `tools_condition`이 `tools` 경로를 고른다. 요청이 없으면 `END`를 고른다.
# 4. `Tool`: `tool_node`가 요청을 실행하고 `ToolMessage`를 만든다.
# 5. `feedback`: `add_messages`가 결과를 State에 합치고 `tools → chatbot` Edge가 모델의 다음 판단으로 돌려보낸다.
# 6. `Out`: 마지막 `AIMessage.tool_calls`가 비면 `END`에서 최종 State를 반환한다.
#
# 그림의 feedback 화살표가 코드의 반복 Edge이다. 모델이 Tool을 더 요청하면 `chatbot → tools → chatbot`이 반복된다.
#
# 공식 그림의 `Tool → Out`은 일반화된 표현이다.
#
# 이 실습에는 `tools → END` Edge가 없으므로 Tool 결과는 항상 `chatbot`으로 돌아가며,
#
# 재호출된 `chatbot`이 Tool 요청 없는 최종 `AIMessage`를 만들 때 Conditional Edge가 `END`를 선택한다.
#
# > 이미지 출처: [LangChain 공식 문서 - Workflows and agents](https://docs.langchain.com/oss/python/langgraph/workflows-agents)

# %%
import dis

from langgraph.graph import END, START, StateGraph
from openai import chat

# 1. Builder 생성
workflow = StateGraph(State)

# 2. Node 등록
workflow.add_node("chatbot", chatbot)
workflow.add_node("tools", tool_node)

# 3. 엣지 연결
workflow.add_edge(START, "chatbot")
workflow.add_edge("tools", "chatbot")

# 4. add_conditional_edges(source, path, path_map)
# - chatbot 실행 뒤 분기 규칙 등록
workflow.add_conditional_edges(
    # 어떤 노드가 끝난 뒤 분기할 것인가
    "chatbot",
    # 다음 목적지를 판단할 함수
    tools_condition,
    {
        # tools_condition 반환 값에 따라
        # 연결될 실제 노드 매핑
        "tools": "tools",
        END: END,
    },
)

# 5. compile() : 실행 가능한 항태로 변경
graph = workflow.compile()
display(graph)

# %% [markdown]
# ## 검색이 필요한 질문의 message 흐름 확인
#
# `invoke(initial_state)`는 LLM을 한 번만 호출하는 메서드가 아니다. `START`부터 `END`까지 이동하며 조건에 따라 chatbot과 tools Node를 여러 번 실행한 뒤 최종 State를 반환한다.
#
# 검색이 한 번 실행되면 `messages`는 보통 다음 순서가 된다. 모델이 추가 검색을 요청하면 가운데 두 단계가 반복될 수 있다.
#
# ```text
# HumanMessage
# → AIMessage(tool_calls: name·args·id)
# → ToolMessage(tool_call_id: 같은 id)
# → 최종 AIMessage(tool_calls: [])
# ```
#
# 전체 State에는 검색 본문과 응답 block도 들어 있다. 아래 코드는 경로를 쉽게 읽도록 message 종류, Tool 이름과 호출 ID만 `list[dict]`로 요약한다.

# %%
from langchain_core.messages import HumanMessage


def summarize_messages(messages: list[AnyMessage]) -> list[dict]:
    """message 본문을 제외하고 종류와 Tool 호출 연결 정보만 반환"""

    return [
        {
            "message_type": message.type,  # human·ai·tool 중 message 종류
            "tool_calls": [  # AIMessage가 요청한 Tool 이름과 호출 ID 목록
                {"name": tool_call["name"], "id": tool_call["id"]}
                for tool_call in getattr(message, "tool_calls", [])
            ],
            # ToolMessage가 아니면 연결할 호출 ID가 없으므로 None을 사용한다.
            "tool_call_id": getattr(message, "tool_call_id", None),
        }
        for message in messages
    ]
    
# 1. 입력준비 
user_input = "LangGraph의 Node와 Edge를 설명하고 필요하면 검색 Tool을 사용해줘"
initial_state = {"messages": [HumanMessage(content=user_input)]}
# 2. 실행 후 결과 번환
final_state = graph.invoke(initial_state)
# 3. 결과 출력
trace_summary = summarize_messages(final_state["messages"])
display(trace_summary)
# Out:
# has_tool_calls: True
# has_tool_calls: False
# [{'message_type': 'human', 'tool_calls': [], 'tool_call_id': None},
#  {'message_type': 'ai',
#   'tool_calls': [{'name': 'tavily_search',
#     'id': 'call_2SRY2Pz3LQwbGorlZQbZnjdx'}],
#   'tool_call_id': None},
#  {'message_type': 'tool',
#   'tool_calls': [],
#   'tool_call_id': 'call_2SRY2Pz3LQwbGorlZQbZnjdx'},
#  {'message_type': 'ai', 'tool_calls': [], 'tool_call_id': None}]

# %% [markdown]
# ## 최종 AIMessage의 content 구조 확인
#
# 마지막 `AIMessage`는 Tool 결과를 읽고 만든 최종 응답이다. Responses API에서는 응답을 다룰 때 다음 세 값을 구분해야 한다.
#
# - `content`: 공급자가 반환한 원본 content이다. 문자열일 수도 있고 block 목록일 수도 있다.
# - `content_blocks`: 공급자별 content를 공통 block 목록으로 정규화한 값이다. block의 종류와 구조를 확인할 때 사용한다.
# - `text`: text block만 모은 문자열이다. 화면 렌더링이나 일반 문자열 처리를 할 때 사용한다.
#
# 아래 코드는 `content_blocks`에서 사용자에게 공개할 `type='text'` block의 `type`과 `text`만 선택한다.

# %%
final_message = final_state["messages"][-1]
public_content_block = [
    {
      "type": block["type"], 
      "text": block.get("text", "")
      }
    for block in final_message.content_blocks
    if block.get("type") == "text"
]
print(public_content_block)
# Out:
# [{'type': 'text', 'text': 'LangGraph에서 **Node(노드)**와 **Edge(엣지)**는 에이전트나 워크플로의 실행 흐름을 정의하는 핵심 요소입니다.\n\n공식 문서에서는 LangGraph를 다음 세 가지로 설명합니다.\n\n- **State**: 애플리케이션의 현재 상태\n- **Node**: 상태를 읽고 작업한 뒤 상태를 갱신하는 함수\n- **Edge**: 다음에 어떤 Node를 실행할지 결정하는 연결 또는 로직  \n  ([LangGraph Graph API](https://docs.langchain.com/oss/python/langgraph/graph-api))\n\n---\n\n## 1. 전체 구조\n\n예를 들어 다음과 같은 고객 문의 처리 흐름이 있다고 하겠습니다.\n\n```text\n사용자 입력\n    ↓\n질문 분류\n    ↓\n ┌───────────────┬───────────────┐\n │               │               │\n기술 문의       환불 문의       기타 문의\n │               │               │\n └───────────────┴───────────────┘\n    ↓\n최종 응답\n```\n\n이를 LangGraph로 표현하면 다음과 같습니다.\n\n- `classify`: 질문을 분류하는 **Node**\n- `technical`, `refund`, `general`: 답변을 생성하는 **Node**\n- `classify`에서 어느 Node로 갈지 결정하는 **조건부 Edge**\n- Node들이 공유하는 대화 내용과 분류 결과: **State**\n\n---\n\n# 2. Node란?\n\nNode는 그래프에서 실제 작업을 수행하는 함수입니다.\n\n일반적으로 Node는 다음 형태를 가집니다.\n\n```text\n현재 State → 작업 수행 → State의 일부 업데이트 반환\n```\n\nPython 예시는 다음과 같습니다.\n\n```python\nfrom typing import TypedDict\n\nclass State(TypedDict):\n    question: str\n    category: str\n    answer: str\n\n\ndef classify_question(state: State):\n    question = state["question"]\n\n    if "환불" in question:\n        category = "refund"\n    elif "오류" in question or "에러" in question:\n        category = "technical"\n    else:\n        category = "general"\n\n    return {"category": category}\n\n\ndef answer_question(state: State):\n    return {\n        "answer": f"일반 문의에 대한 답변입니다: {state[\'question\']}"\n    }\n```\n\nNode는 전체 State를 반드시 전부 반환할 필요가 없습니다.\n\n```python\nreturn {"category": "refund"}\n```\n\n처럼 **변경할 필드만 반환**할 수 있습니다. LangGraph가 이 업데이트를 기존 State에 반영합니다.\n\n## Node에서 할 수 있는 일\n\nNode는 단순한 Python 함수일 수도 있고, 다음과 같은 작업을 수행할 수도 있습니다.\n\n- LLM 호출\n- 외부 API 호출\n- 데이터베이스 조회\n- 문서 검색\n- 사용자 입력 검증\n- 조건 판단\n- 도구 호출\n- 여러 결과의 조합\n- 에러 처리 또는 재시도\n\n따라서 Node는 반드시 LLM일 필요가 없습니다.\n\n```python\ndef search_database(state: State):\n    result = database.search(state["question"])\n    return {"answer": result}\n\n\ndef call_llm(state: State):\n    response = llm.invoke(state["question"])\n    return {"answer": response.content}\n```\n\n즉, Node는 **“그래프 안에서 실행되는 하나의 작업 단위”**라고 이해하면 됩니다.\n\n---\n\n# 3. Edge란?\n\nEdge는 Node 사이의 실행 순서를 연결합니다.\n\n## 일반 Edge\n\n항상 같은 다음 Node로 이동하는 경우에는 일반 Edge를 사용합니다.\n\n```python\ngraph.add_edge("classify", "answer")\n```\n\n이 의미는 다음과 같습니다.\n\n```text\nclassify가 끝나면 answer를 실행한다\n```\n\n시작과 끝에는 특수한 `START`, `END`를 사용할 수 있습니다.\n\n```python\nfrom langgraph.graph import START, END\n\ngraph.add_edge(START, "classify")\ngraph.add_edge("answer", END)\n```\n\n- `START`: 그래프 실행 시작 지점\n- `END`: 그래프 실행 종료 지점\n\n`START`와 `END`는 일반적인 작업 Node라기보다는 그래프의 시작과 종료를 나타내는 특수한 지점입니다.  \n([공식 Graph API 문서](https://docs.langchain.com/oss/python/langgraph/graph-api))\n\n---\n\n## 조건부 Edge\n\n현재 State에 따라 다음 Node가 달라지는 경우에는 조건부 Edge를 사용합니다.\n\n```python\ndef route_question(state: State):\n    return state["category"]\n```\n\n이 라우팅 함수를 Edge에 연결합니다.\n\n```python\ngraph.add_conditional_edges(\n    "classify",\n    route_question,\n    {\n        "technical": "technical_answer",\n        "refund": "refund_answer",\n        "general": "general_answer",\n    },\n)\n```\n\n전체 흐름은 다음과 같습니다.\n\n```text\nclassify\n   │\n   ├── "technical" → technical_answer\n   ├── "refund"    → refund_answer\n   └── "general"   → general_answer\n```\n\n여기서 `route_question`은 작업을 수행하는 주 Node라기보다는 **다음 경로를 결정하는 라우팅 함수**입니다.\n\n조건부 Edge를 사용하면 다음과 같은 패턴을 만들 수 있습니다.\n\n- 질문 유형별 분기\n- 품질 검사 후 재생성\n- 승인 또는 거절\n- 도구 호출 여부 판단\n- 검색 결과가 있으면 답변, 없으면 추가 검색\n- 최대 반복 횟수 확인\n- 사람 검토 단계로 이동\n\n---\n\n# 4. 간단한 전체 예제\n\n```python\nfrom typing import TypedDict\n\nfrom langgraph.graph import StateGraph, START, END\n\n\nclass State(TypedDict):\n    question: str\n    category: str\n    answer: str\n\n\ndef classify_question(state: State):\n    question = state["question"]\n\n    if "환불" in question:\n        return {"category": "refund"}\n\n    if "오류" in question or  ...

# %% [markdown]
# ## Tool이 필요 없는 질문의 짧은 경로
#
# 같은 그래프라도 모델이 `tool_calls`를 만들지 않으면 Tool Node를 거치지 않는다. 일반적인 의견 질문을 넣어 `START → chatbot → END`의 짧은 경로와 앞의 반복 경로를 비교한다.
#
# 모델의 Tool 선택은 확률적일 수 있으므로 질문 문장만 보고 경로를 단정하지 않고, 마지막 `AIMessage.tool_calls`와 분기 로그를 확인한다.

# %%
user_input = "AI가 인간의 삶을 어떻게 변화시킬지 마크다운 형식으로 정리해줘"
initial_state = {"messages": [HumanMessage(content=user_input)]}

final_state = graph.invoke(initial_state)

trace_summary = summarize_messages(final_state["messages"])
print(trace_summary)
# Out:
# has_tool_calls: False
# [{'message_type': 'human', 'tool_calls': [], 'tool_call_id': None}, {'message_type': 'ai', 'tool_calls': [], 'tool_call_id': None}]

# %% [markdown]
# ## 최종 텍스트를 Markdown으로 렌더링하기
#
# `Markdown()`은 문자열을 받아 제목·목록 같은 Markdown 문법을 화면에 렌더링한다. 원본 `AIMessage.content`는 block 목록일 수 있으므로 문자열 인자가 필요한 곳에 그대로 전달하지 않는다.
#
# 앞에서 구분한 `AIMessage.text`를 사용하면 State와 원본 content 구조는 유지하면서 사용자에게 보여 줄 텍스트만 문자열로 꺼낼 수 있다.

# %%
from IPython.display import Markdown

final_message = final_state["messages"][-1]

answer_text = "\n".join(
    block.get("text", "")
    for block in final_message.content_blocks
    if block.get("type") == "text"
)

display(Markdown(answer_text))
# Out:
# - **일자리:** 반복 업무가 자동화되고, 새로운 직업과 업무 방식이 등장할 것입니다.
# - **교육:** 개인별 맞춤 학습과 실시간 피드백이 더욱 쉬워질 것입니다.
# - **의료:** 질병 예측, 진단 보조, 신약 개발이 발전할 것입니다.
# - **일상생활:** 번역, 정보 검색, 가사·일정 관리가 편리해질 것입니다.
# - **사회적 과제:** 개인정보 보호, 일자리 불평등, AI 윤리 문제가 중요해질 것입니다.

# %% [markdown]
# ## 직접 구현을 prebuilt 구성 요소로 교체하기
#
# 앞에서는 Tool 요청과 결과의 연결 원리를 보기 위해 Tool Node와 route function을 직접 구현했다.
#
# 실제 프로젝트에서는 LangGraph가 제공하는 prebuilt 구성 요소로 같은 역할을 짧게 구성할 수 있다.
#
# ### 직접 구현
#
# - `name·args·id → Tool 실행 → ToolMessage` 변환을 코드로 확인하기 좋다.
# - 입력 검증과 예외 처리 범위를 직접 정해야 한다.
#
# ### prebuilt 구현
#
# - `PrebuiltToolNode`: 마지막 `AIMessage.tool_calls`를 실행하고 같은 ID의 `ToolMessage`를 반환한다. 병렬 Tool 호출과 오류 처리도 지원한다.
# - `prebuilt_tools_condition`: 마지막 message에 요청이 있으면 `"tools"`, 없으면 `"__end__"`를 반환한다.
#
# 두 반환값이 이미 등록한 `tools` Node와 LangGraph 종료 지점의 이름이므로 이 셀에서는 별도 `path_map`을 생략한다.

# %%
from langgraph.graph import START, StateGraph
from langgraph.prebuilt import ToolNode as PrebuiltToolNode
from langgraph.prebuilt import tools_condition as prebuilt_tools_condition

prebuild_tool_node = PrebuiltToolNode(tools)


prebuild_workflow = StateGraph(State)
prebuild_workflow.add_node("chatbot", chatbot)
prebuild_workflow.add_node("tools", prebuild_tool_node)

prebuild_workflow.add_edge(START, "chatbot")
prebuild_workflow.add_edge("tools", "chatbot")

prebuild_workflow.add_conditional_edges(
    
    "chatbot",
    # tool 요청 유무로 다음 노드 판별하는 함수
    prebuilt_tools_condition,
)

prebuild_graph = prebuild_workflow.compile()
display(prebuild_graph)

# %%
from email import message

user_input = "LangGraph PreBuuilt에 대해서 검색 Tool 사용해서 알려줘"
initial_state = {"messages": [HumanMessage(content=user_input)]}

final_state = prebuild_graph.invoke(initial_state)
trace_summary = summarize_messages(final_state["messages"])
print(trace_summary)

Markdown(final_state["messages"][-1].text)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[46], line 6
#       2
#       3 user_input = "LangGraph PreBuuilt에 대해서 검색 Tool 사용해서 알려줘"
#       4 initial_state = {"message": [HumanMessage(content=user_input)]}
#       5
# ----> 6 final_state = prebuild_graph.invoke(initial_state)
#       7 trace_summary = summarize_messages(final_state["messages"])
#       8 print(trace_summary)
#       9
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langgraph/pregel/main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langgraph/pregel/main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langgraph/pregel/_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langgraph/pregel/_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:707, in RunnableSeq.invoke(self, input, config, **kwargs)
#     705     # run in context
#     706     with set_config_context(config, run) as context:
# --> 707         input = context.run(step.invoke, input, config, **kwargs)
#     708 else:
#     709     input = step.invoke(input, config)
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:447, in RunnableCallable.invoke(self, input, config, **kwargs)
#     445         run_manager.on_chain_end(ret)
#     446 else:
# --> 447     ret = self.func(*args, **kwargs)
#     448 if self.recurse and isinstance(ret, Runnable):
#     449     return ret.invoke(input, config)
#
# Cell In[28], line 14, in chatbot(state)
#      11 def chatbot(state: State) -> dict:
#      12     # State의 메시지를 tool이 묶여있는 LLM에 전달
#      13     # -> tool 사용 조건은 아래에서 정의할 예정
# ---> 14     response = llm_with_tools.invoke(state["messages"])
#      15     return {"messages": [response]}
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langchain_core/runnables/base.py:6002, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5995 @override
#    5996 def invoke(
#    5997     self,
#    (...)   6000     **kwargs: Any | None,
#    6001 ) -> Output:
# -> 6002     return self.bound.invoke(
#    6003         input,
#    6004         self._merge_configs(config),
#    6005         **{**self.kwargs, **kwargs},
#    6006     )
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1865, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1856 @override
#    1857 def generate_prompt(
#    1858     self,
#    (...)   1862     **kwargs: Any,
#    1863 ) -> LLMResult:
#    1864     prompt_messages = [p.to_messages() for p in prompts]
# -> 1865     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1672, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1669 for i, m in enumerate(input_messages):
#    1670     try:
#    1671         results.append(
# -> 1672             self._generate_with_cache(
#    1673                 m,
#    1674                 stop=stop,
#    1675                 run_manager=run_managers[i] if run_managers else None,
#    1676                 **kwargs,
#    1677             )
#    1678         )
#    1679     except BaseException as e:
#    1680         if run_managers:
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:2010, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2008     result = generate_from_stream(iter(chunks))
#    2009 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2010     result = self._generate(
#    2011         messages, stop=stop, run_manager=run_manager, **kwargs
#    2012     )
#    2013 else:
#    2014     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1750, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1748         response = raw_response.parse()
#    1749 except openai.BadRequestError as e:
# -> 1750     _handle_openai_bad_request(e)
#    1751 except openai.APIError as e:
#    1752     _handle_openai_api_error(e)
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1734, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1730     raw_response = self.root_client.responses.with_raw_response.parse(
#    1731         **payload
#    1732     )
#    1733 else:
# -> 1734     raw_response = self.root_client.responses.with_raw_response.create(
#    1735         **payload
#    1736     )
#    1737 response = raw_response.parse()
#    1738 if self.include_response_headers:
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/openai/_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     365 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/openai/resources/responses/responses.py:1028, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     987 def create(
#     988     self,
#     989     *,
#    (...)   1026     timeout: float | httpx2.Timeout | None | NotGiven = not_given,
#    1027 ) -> Response | Stream[ResponseStreamEvent]:
# -> 1028     return self._post(
#    1029         "/responses",
#    1030         body=maybe_transform(
#    1031             {
#    1032                 "background": background,
#    1033                 "context_management": context_management,
#    1034                 "conversation": conversation,
#    1035                 "include": include,
#    1036                 "input": input,
#    1037                 "instructions": instructions,
#    1038                 "max_output_tokens": max_output_tokens,
#    1039                 "max_tool_calls": max_tool_calls,
#    1040                 "metadata": metadata,
#    1041                 "model": model,
#    1042                 "moderation": moderation,
#    1043                 "parallel_tool_calls": parallel_tool_calls,
#    1044                 "previous_response_id": previous_response_id,
#    1045                 "prompt": prompt,
#    1046                 "prompt_cache_key": prompt_cache_key,
#    1047                 "prompt_cache_options": prompt_cache_options,
#    1048                 "prompt_cache_retention": prompt_cache_retention,
#    1049                 "reasoning": reasoning,
#    1050                 "safety_identifier": safety_identifier,
#    1051                 "service_tier": service_tier,
#    1052                 "store": store,
#    1053                 "stream": stream,
#    1054                 "stream_options": stream_options,
#    1055                 "temperature": temperature,
#    1056                 "text": text,
#    1057                 "tool_choice": tool_choice,
#    1058                 "tools": tools,
#    1059                 "top_logprobs": top_logprobs,
#    1060                 "top_p": top_p,
#    1061                 "truncation": truncation,
#    1062                 "user": user,
#    1063             },
#    1064             response_create_params.ResponseCreateParamsStreaming
#    1065             if stream
#    1066             else response_create_params.ResponseCreateParamsNonStreaming,
#    1067         ),
#    1068         options=make_request_options(
#    1069             extra_headers=extra_headers,
#    1070             extra_query=extra_query,
#    1071             extra_body=extra_body,
#    1072             timeout=timeout,
#    1073             security={"bearer_auth": True},
#    1074         ),
#    1075         cast_to=Response,
#    1076         stream=stream or False,
#    1077         stream_cls=Stream[ResponseStreamEvent],
#    1078     )
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/openai/_base_client.py:1382, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1373     warnings.warn(
#    1374         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1375         "Please pass raw bytes via the `content` parameter instead.",
#    1376         DeprecationWarning,
#    1377         stacklevel=2,
#    1378     )
#    1379 opts = FinalRequestOptions.construct(
#    1380     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1381 )
# -> 1382 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/envs/llm_env/lib/python3.12/site-packages/openai/_base_client.py:1155, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1152             err.response.read()
#    1154         log.debug("Re-raising status error")
# -> 1155         raise self._make_status_error_from_response(err.response) from None
#    1157     break
#    1159 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'One of "input" or "previous_response_id" or \'prompt\' or \'conversation\' must be provided.', 'type': 'invalid_request_error', 'param': None, 'code': 'missing_required_parameter'}}
# During task with name 'chatbot' and id 'ca3af20c-b7c1-c97f-2276-04186c691ac8'
